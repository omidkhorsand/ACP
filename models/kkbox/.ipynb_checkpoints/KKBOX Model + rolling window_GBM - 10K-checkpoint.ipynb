# %% [markdown]
# ## Using the RollingWindow class on KKBOX

# %%
import pandas as pd 
import numpy as np
import featuretools as ft
import featuretools.variable_types as vtypes
from featuretools.variable_types import Datetime, Timedelta, Variable
import glob
from RollingWindow import RollingWindow

# %%
# Read in all data
members = pd.read_csv('members_v3_1k.csv', 
                      parse_dates=['registration_init_time'], 
                      infer_datetime_format = True, 
                      dtype = {'gender': 'category'})

trans = pd.read_csv('transactions_1k.csv',
                   parse_dates=['transaction_date', 'membership_expire_date'], 
                    infer_datetime_format = True)

logs = pd.read_csv('user_logs_1k.csv', parse_dates = ['date'])

cutoff_times = pd.read_csv('label_times.csv', parse_dates = ['cutoff_time'])

# Make empty entityset
es = ft.EntitySet(id = 'customers')

trans = trans[trans['membership_expire_date'] > trans['transaction_date']]
# Create entity from transactions
es.entity_from_dataframe(entity_id='transactions', dataframe=trans,
                         index = 'transactions_index', make_index = True,
                         time_index = 'transaction_date', 
                         variable_types = {'payment_method_id': vtypes.Categorical, 
                                           'is_auto_renew': vtypes.Boolean, 'is_cancel': vtypes.Boolean})
# Create entity from members
es.entity_from_dataframe(entity_id='members', dataframe=members,
                         index = 'msno', time_index = 'registration_init_time', 
                         variable_types = {'city': vtypes.Categorical, 
                                           'registered_via': vtypes.Categorical})
#Create entity from user logs
es.entity_from_dataframe(entity_id='logs', dataframe=logs,
                         index = 'logs_index', make_index = True,
                         time_index = 'date')

# Relationships (parent, child)
r_member_transactions = ft.Relationship(es['members']['msno'], es['transactions']['msno'])
r_member_logs = ft.Relationship(es['members']['msno'], es['logs']['msno'])

es.add_relationships([r_member_transactions, r_member_logs])

# Removing duplicates from cutoff table
cutoff_times = cutoff_times.drop_duplicates(subset = ['msno', 'cutoff_time'])

# %%
# Specify aggregation primitives
agg_primitives = ['sum', 'time_since_last', 'avg_time_between', 'all', 'mode', 'num_unique', 'min', 'last', 
                  'mean', 'percent_true', 'max', 'std', 'count']
# Specify transformation primitives
trans_primitives = ['weekend', 'cum_sum', 'day', 'month', 'diff', 'time_since_previous']

# %%
from timeit import default_timer as timer

start = timer()

kkbox_mo = RollingWindow(es)
kkbox_mo.add_agg_primitives(agg_primitives)
kkbox_mo.add_trans_primitives(trans_primitives)
training_window = [3,6]
kkbox_mo.dfsRolling('members', 'monthly', training_window, cutoff_times, max_depth=3, chunk_size=1000)

end = timer()
print('%f seconds elapsed.'%round(end - start))
# Out:
# The aggregate primitives have been added:  sum time_since_last avg_time_between all mode num_unique min last mean percent_true max std count
# The transformative primitives have been added:  weekend cum_sum day month diff time_since_previous
# Built 118 features
# Elapsed: 02:32 | Remaining: 00:00 | Progress: 100%|██████████| Calculated: 22/22 chunks
# 2019-03-08 12:08:27,567 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-03-08 12:08:27,578 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-03-08 12:08:27,615 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-03-08 12:08:28,269 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-03-08 12:08:28,280 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-03-08 12:08:28,315 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-03-08 12:08:29,021 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-03-08 12:08:29,032 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-03-08 12:08:29,069 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-03-08 12:08:29,701 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-03-08 12:08:29,712 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-03-08 12:08:29,752 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-03-08 12:08:30,464 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-03-08 12:08:30,477 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-03-08 12:08:30,514 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-03-08 12:08:31,234 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-03-08 12:08:31,245 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-03-08 12:08:31,281 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-03-08 12:08:32,076 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-03-08 12:08:32,087 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-03-08 12:08:32,124 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-03-08 12:08:32,850 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-03-08 12:08:32,863 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-03-08 12:08:32,904 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-03-08 12:08:33,614 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-03-08 12:08:33,626 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-03-08 12:08:33,663 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-03-08 12:08:34,265 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-03-08 12:08:34,276 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-03-08 12:08:34,312 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-03-08 12:08:35,023 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-03-08 12:08:35,034 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-03-08 12:08:35,074 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-03-08 12:08:35,854 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-03-08 12:08:35,867 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-03-08 12:08:35,905 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-03-08 12:08:36,814 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-03-08 12:08:36,826 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-03-08 12:08:36,865 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-03-08 12:08:37,695 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-03-08 12:08:37,707 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-03-08 12:08:37,744 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-03-08 12:08:38,529 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-03-08 12:08:38,540 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-03-08 12:08:38,579 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-03-08 12:08:39,356 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-03-08 12:08:39,367 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-03-08 12:08:39,405 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-03-08 12:08:39,768 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-03-08 12:08:39,778 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-03-08 12:08:39,815 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-03-08 12:08:40,567 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-03-08 12:08:40,579 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-03-08 12:08:40,620 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-03-08 12:08:41,088 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-03-08 12:08:41,099 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-03-08 12:08:41,137 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-03-08 12:08:41,939 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-03-08 12:08:41,950 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-03-08 12:08:41,987 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-03-08 12:08:42,723 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-03-08 12:08:42,734 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-03-08 12:08:42,772 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-03-08 12:08:43,269 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-03-08 12:08:43,280 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-03-08 12:08:43,318 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-03-08 12:08:43,961 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-03-08 12:08:43,972 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-03-08 12:08:44,008 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-03-08 12:08:44,453 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-03-08 12:08:44,463 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-03-08 12:08:44,498 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-03-08 12:08:44,991 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-03-08 12:08:45,003 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-03-08 12:08:45,039 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-03-08 12:08:45,443 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-03-08 12:08:45,455 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-03-08 12:08:45,490 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-03-08 12:08:45,944 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-03-08 12:08:45,955 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-03-08 12:08:45,991 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-03-08 12:08:46,755 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-03-08 12:08:46,766 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-03-08 12:08:46,803 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-03-08 12:08:47,824 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-03-08 12:08:47,837 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-03-08 12:08:47,875 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-03-08 12:08:48,894 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-03-08 12:08:48,907 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-03-08 12:08:48,944 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-03-08 12:08:49,941 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-03-08 12:08:49,954 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-03-08 12:08:49,995 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-03-08 12:08:51,029 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-03-08 12:08:51,040 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-03-08 12:08:51,078 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-03-08 12:08:52,141 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-03-08 12:08:52,154 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-03-08 12:08:52,198 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-03-08 12:08:53,367 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-03-08 12:08:53,378 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-03-08 12:08:53,416 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-03-08 12:08:54,508 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-03-08 12:08:54,519 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-03-08 12:08:54,559 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-03-08 12:08:55,761 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-03-08 12:08:55,772 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-03-08 12:08:55,808 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-03-08 12:08:56,640 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-03-08 12:08:56,652 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-03-08 12:08:56,696 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-03-08 12:08:57,874 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-03-08 12:08:57,885 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-03-08 12:08:57,925 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-03-08 12:08:59,175 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-03-08 12:08:59,187 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-03-08 12:08:59,227 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-03-08 12:09:00,513 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-03-08 12:09:00,525 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-03-08 12:09:00,564 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-03-08 12:09:01,803 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-03-08 12:09:01,814 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-03-08 12:09:01,854 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-03-08 12:09:03,093 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-03-08 12:09:03,105 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-03-08 12:09:03,147 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-03-08 12:09:04,302 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-03-08 12:09:04,313 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-03-08 12:09:04,351 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-03-08 12:09:04,740 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-03-08 12:09:04,751 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-03-08 12:09:04,789 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-03-08 12:09:05,809 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-03-08 12:09:05,820 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-03-08 12:09:05,857 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-03-08 12:09:06,455 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-03-08 12:09:06,467 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-03-08 12:09:06,511 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-03-08 12:09:07,434 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-03-08 12:09:07,447 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-03-08 12:09:07,485 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-03-08 12:09:08,278 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-03-08 12:09:08,289 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-03-08 12:09:08,326 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-03-08 12:09:08,913 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-03-08 12:09:08,923 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-03-08 12:09:08,962 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-03-08 12:09:09,715 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-03-08 12:09:09,727 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-03-08 12:09:09,768 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-03-08 12:09:10,316 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-03-08 12:09:10,328 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-03-08 12:09:10,370 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-03-08 12:09:10,970 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-03-08 12:09:10,981 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-03-08 12:09:11,021 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-03-08 12:09:11,622 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-03-08 12:09:11,634 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-03-08 12:09:11,673 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-03-08 12:09:12,304 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-03-08 12:09:12,315 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-03-08 12:09:12,352 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# ---> 24 columns dropped due to duplicate values:
#
# 210.000000 seconds elapsed.

# %% [markdown]
# Features generated:

# %% [markdown]
# Calling the merged feature matrix using self.df. As shown below, features were generated using the 3 month and 6 month lookback from the cutoff date. Only the first instance of duplicate columns were kept, such as city and gender. City and gender at 3 months and 6 months are the same and hence the duplicate was removed.

# %%
kkbox_mo.df.shape
# Out:
# (18651, 339)

# %%
fm = kkbox_mo.df.copy()
fm = fm.reset_index()
fm.drop(columns=["days_to_churn", "churn_date"], inplace=True)
fm = fm.dropna(subset=["label"])
fm = fm.drop_duplicates(subset = ['msno', 'time'])
fm = pd.get_dummies(fm.drop(columns=['time', 'msno']))
fm = fm[(fm.bd<120) & (fm.bd>6)]
fm = fm.fillna(fm.mean())

# %% [markdown]
# ## Pipeline

# %%
from FeatureSelection import RFPipeline

# %%
X = fm.drop(columns=['label'])
y = fm['label']
kkbox_reduced = RFPipeline.fit_transform(X, y)
# Out:
# ---> 0 columns dropped due to missing values: []
# ---> 6 columns dropped due to duplicate values:
#
# ---> 1 columns dropped due to zero variance:
#  ['LAST(transactions.is_cancel)_3mos']
# ---> 107 columns dropped due to collinearity:
#  ['MAX(logs.num_100)', 'MAX(logs.total_secs)', 'STD(logs.num_25)', 'MEAN(transactions.plan_list_price)', 'STD(transactions.actual_amount_paid)', 'MAX(transactions.payment_plan_days)', 'TIME_SINCE_LAST(logs.date)', 'MEAN(transactions.payment_plan_days)', 'LAST(transactions.payment_plan_days)', 'SUM(transactions.actual_amount_paid)', 'MAX(transactions.plan_list_price)', 'LAST(transactions.plan_list_price)', 'MEAN(transactions.actual_amount_paid)', 'LAST(transactions.actual_amount_paid)', 'MIN(transactions.payment_plan_days)', 'SUM(logs.num_50)', 'MIN(transactions.plan_list_price)', 'SUM(transactions.plan_list_price)', 'COUNT(transactions)', 'STD(transactions.payment_plan_days)', 'MODE(transactions.payment_method_id)', 'NUM_UNIQUE(transactions.MONTH(membership_expire_date))', 'MIN(transactions.actual_amount_paid)_3mos', 'MAX(logs.total_secs)_3mos', 'STD(logs.num_25)_3mos', 'MEAN(transactions.plan_list_price)_3mos', 'MAX(transactions.payment_plan_days)_3mos', 'MEAN(transactions.payment_plan_days)_3mos', 'LAST(transactions.payment_plan_days)_3mos', 'STD(logs.num_50)_3mos', 'SUM(transactions.actual_amount_paid)_3mos', 'STD(logs.total_secs)_3mos', 'LAST(logs.total_secs)_3mos', 'MEAN(logs.total_secs)_3mos', 'SUM(logs.num_100)_3mos', 'MAX(transactions.plan_list_price)_3mos', 'MAX(logs.num_unq)_3mos', 'LAST(transactions.plan_list_price)_3mos', 'STD(logs.num_75)_3mos', 'MAX(logs.num_25)_3mos', 'MEAN(transactions.actual_amount_paid)_3mos', 'MIN(transactions.payment_plan_days)_3mos', 'SUM(logs.num_50)_3mos', 'MIN(transactions.plan_list_price)_3mos', 'SUM(transactions.plan_list_price)_3mos', 'MIN(logs.total_secs)_3mos', 'STD(transactions.payment_plan_days)_3mos', 'COUNT(logs)_3mos', 'SUM(logs.total_secs)_3mos', 'MIN(logs.num_75)_3mos', 'MODE(transactions.payment_method_id)_3mos', 'MODE(transactions.DAY(membership_expire_date))_3mos', 'NUM_UNIQUE(transactions.MONTH(membership_expire_date))_3mos', 'MONTH(LAST(transactions.transaction_date))_3mos', 'MODE(transactions.MONTH(membership_expire_date))_3mos', 'MIN(transactions.actual_amount_paid)_6mos', 'MIN(logs.num_50)_6mos', 'MAX(logs.total_secs)_6mos', 'STD(logs.num_25)_6mos', 'MEAN(transactions.plan_list_price)_6mos', 'MIN(logs.num_25)_6mos', 'MAX(transactions.payment_plan_days)_6mos', 'MEAN(transactions.payment_plan_days)_6mos', 'LAST(transactions.payment_plan_days)_6mos', 'SUM(transactions.actual_amount_paid)_6mos', 'STD(logs.total_secs)_6mos', 'LAST(logs.total_secs)_6mos', 'MEAN(logs.total_secs)_6mos', 'SUM(logs.num_100)_6mos', 'MAX(transactions.plan_list_price)_6mos', 'LAST(transactions.plan_list_price)_6mos', 'STD(logs.num_75)_6mos', 'MAX(logs.num_25)_6mos', 'MEAN(transactions.actual_amount_paid)_6mos', 'LAST(transactions.actual_amount_paid)_6mos', 'MIN(logs.num_unq)_6mos', 'MIN(transactions.payment_plan_days)_6mos', 'SUM(logs.num_50)_6mos', 'MIN(transactions.plan_list_price)_6mos', 'SUM(transactions.plan_list_price)_6mos', 'MIN(logs.total_secs)_6mos', 'COUNT(transactions)_6mos', 'STD(transactions.payment_plan_days)_6mos', 'PERCENT_TRUE(transactions.is_cancel)_6mos', 'COUNT(logs)_6mos', 'SUM(logs.total_secs)_6mos', 'MIN(logs.num_75)_6mos', 'MODE(transactions.payment_method_id)_6mos', 'LAST(logs.num_50)_6mos', 'NUM_UNIQUE(transactions.MONTH(transaction_date))_6mos', 'NUM_UNIQUE(logs.MONTH(date))_6mos', 'NUM_UNIQUE(transactions.MONTH(membership_expire_date))_6mos', 'gender_male', 'ALL(transactions.is_auto_renew)_True', 'LAST(transactions.WEEKEND(transaction_date))_False', 'LAST(logs.WEEKEND(date))_False', 'ALL(transactions.is_auto_renew)_3mos_True', 'ALL(transactions.is_cancel)_3mos_False', 'ALL(logs.WEEKEND(date))_3mos_False', 'ALL(transactions.WEEKEND(transaction_date))_3mos_False', 'ALL(transactions.WEEKEND(membership_expire_date))_3mos_False', 'LAST(transactions.WEEKEND(membership_expire_date))_3mos_False', 'ALL(transactions.is_auto_renew)_6mos_True', 'ALL(transactions.is_cancel)_6mos_False', 'ALL(logs.WEEKEND(date))_6mos_False', 'ALL(transactions.WEEKEND(transaction_date))_6mos_False', ...

# %%
#RFPipeline.named_steps["RF_selector"].plot_importance()

# %%
kkbox_reduced.shape
# Out:
# (7497, 51)

# %% [markdown]
# ## Gradient Boosting

# %%
import lightgbm as lgb

RSEED = 40

def cross_validate(X, y):
    """Compute cross validation ROC AUC of a gradient boosting model for a given training dataset"""
    
    # Extract the labels
    train_labels = y
    train = X

    # Create a  lgb training set
    train_set = lgb.Dataset(train, label = train_labels)

    # Find default hyperparameters
    model = lgb.LGBMClassifier()
    params = model.get_params()

    # Number of estimators will be selected through early stopping
    del params['n_estimators'], params['silent']

    # Early stoppping with 5 fold cross validation
    cv_results = lgb.cv(params, train_set, num_boost_round = 10000, metrics = 'auc', 
                        early_stopping_rounds = 100, seed = RSEED, nfold = 5)

    print('Cross Validation ROC AUC: {:.5f} with std: {:.5f}.'.format(cv_results['auc-mean'][-1],
                                                                               cv_results['auc-stdv'][-1]))

    print('Number of estimators trained: {}'.format(len(cv_results['auc-mean'])))
    
    return cv_results

# %%
cv_results_baseline = cross_validate(kkbox_reduced, y)
# Out:
# Cross Validation ROC AUC: 0.87344 with std: 0.01760.
# Number of estimators trained: 43

# %%
## Feature Importance
X = kkbox_reduced

# New model fit on the training data
model = lgb.LGBMClassifier(n_estimators = len(cv_results_baseline['auc-mean']), random_state = RSEED)
model.fit(X, y)

# Put feature importances into a dataframe
feature_importances = pd.DataFrame({'feature': list(X.columns), 
                                    'importance': model.feature_importances_})

import matplotlib.pyplot as plt

def plot_feature_importances(df):
    
    plt.rcParams['font.size'] = 18
    
    # Sort features according to importance
    df = df.sort_values('importance', ascending = False).reset_index()
    
    # Normalize the feature importances to add up to one
    df['importance_normalized'] = df['importance'] / df['importance'].sum()
    df['cumulative_importance'] = np.cumsum(df['importance_normalized'])

    # Make a horizontal bar chart of feature importances
    plt.figure(figsize = (10, 6))
    ax = plt.subplot()
    
    # Need to reverse the index to plot most important on top
    ax.barh(list(reversed(list(df.index[:15]))), 
            df['importance_normalized'].head(15), 
            align = 'center', edgecolor = 'k')
    
    # Set the yticks and labels
    ax.set_yticks(list(reversed(list(df.index[:15]))))
    ax.set_yticklabels(df['feature'].head(15))
    
    # Plot labeling
    plt.xlabel('Normalized Importance'); plt.title('Feature Importances')
    plt.show()

    
    return df
norm_fi = plot_feature_importances(feature_importances)
norm_fi.head(20)
# Out:
#     index                                          feature  importance  \
# 0       0   TIME_SINCE_LAST(transactions.transaction_date)         147
# 1      19  AVG_TIME_BETWEEN(transactions.transaction_date)          51
# 2      16         LAST(transactions.DAY(transaction_date))          48
# 3      36   LAST(transactions.DAY(membership_expire_date))          47
# 4      20                               LAST(logs.num_unq)          44
# 5       9                      AVG_TIME_BETWEEN(logs.date)          43
# 6      14                 PERCENT_TRUE(logs.WEEKEND(date))          38
# 7      47                                MEAN(logs.num_50)          35
# 8       4              SUM(transactions.payment_plan_days)          34
# 9      12                            LAST(logs.total_secs)          34
# 10     45                                               bd          33
# 11     15                           MONTH(LAST(logs.date))          33
# 12     24                             MODE(logs.DAY(date))          30
# 13     25                                 STD(logs.num_50)          29
# 14      3       MONTH(LAST(transactions.transaction_date))          29
# 15     39                               MEAN(logs.num_985)          28
# 16     29         MODE(transactions.DAY(transaction_date))          27
# 17     13                                 STD(logs.num_75)          26
# 18     18                                STD(logs.num_985)          26
# 19     41                                LAST(logs.num_25)          26
#
#     importance_normalized  cumulative_importance
# 0                0.113953               0.113953
# 1                0.039535               0.153488
# 2                0.037209               0.190698
# 3                0.036434               0.227132
# 4                0.034109               0.261240
# 5                0.033333               0.294574
# 6                0.029457               0.324031
# 7                0.027132               0.351163
# 8                0.026357               0.377519
# 9                0.026357               0.403876
# 10               0.025581               0.429457
# 11               0.025581               0.455039
# 12               0.023256               0.478295
# 13               0.022481               0.500775
# 14               0.022481               0.523256
# 15               0.021705               0.544961
# 16               0.020930               0.565891
# 17               0.020155               0.586047
# 18               0.020155               0.606202
# 19               0.020155               0.626357
