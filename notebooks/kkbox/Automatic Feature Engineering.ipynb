# %% [markdown]
# # KKBOX Feature Engineering
# In this notebook, we will run feature extraction and selection using the `FeatureExtraction` class and automated modelling pipeline from `FeatureSelection.py` on the KKBOX dataset. KKBOX is a music subscription service that serves as a good example of how we can use the automated modelling pipeline to help model churn.
#
# For our purposes we randomly subsampled 1,000 users from the dataset. The methodology to create the cutoff times was replicated from the Featuretools customer churn demo, which can be found here: https://github.com/Featuretools/predict-customer-churn/tree/master/churn

# %%
import pandas as pd 
import numpy as np
import featuretools as ft
import featuretools.variable_types as vtypes
from featuretools.variable_types import Datetime, Timedelta, Variable
from FeatureExtraction import FeatureExtraction

# %% [markdown]
# ## Importing Datasets
#
# KKBOX has 4 main tables:
# * `members` contains information on each member such as gender, city, and first registration time
# * `trans` contains the transactional data of each member including transaction date and membership expiry date
# * `logs` refers to the user log information for each member on specific dates such as the number of songs listened to for 25% of the song length, 100% of the song length, number of unique songs listened to, etc.
# * `cutoff_times` refers to the cutoff date for extracting features. Since customers can churn multiple times in their customer lifecycle, each user id can have multiple cutoff dates.

# %%
members = pd.read_csv('members_v3_1k.csv', 
                      parse_dates=['registration_init_time'], 
                      infer_datetime_format = True, 
                      dtype = {'gender': 'category'})

trans = pd.read_csv('transactions_1k.csv',
                   parse_dates=['transaction_date', 'membership_expire_date'], 
                    infer_datetime_format = True)
# Filter only rows that are valid from transactions
trans = trans[trans['membership_expire_date'] > trans['transaction_date']]

logs = pd.read_csv('user_logs_1k.csv', parse_dates = ['date'])

cutoff_times = pd.read_csv('label_times.csv', parse_dates = ['cutoff_time'])
# Removing duplicates from cutoff table
cutoff_times = cutoff_times.drop_duplicates(subset = ['msno', 'cutoff_time'])

# %% [markdown]
# ## Creating Featuretools `EntitySets`
#
# The FeatureExtraction class is dependent on creating `EntitySets` and defining their relationships as per Featuretools documentation. Thus, we create `entities` for `trans`, `members`, and `logs`, with `members` being the parent table and `logs` and `trans` its children.

# %%
# Make empty entityset
es = ft.EntitySet(id = 'customers')

# Create entity from transactions
es.entity_from_dataframe(entity_id='transactions', dataframe=trans,
                         index = 'transactions_index', make_index = True,
                         time_index = 'transaction_date', 
                         variable_types = {'payment_method_id': vtypes.Categorical, 
                                           'is_auto_renew': vtypes.Boolean, 'is_cancel': vtypes.Boolean})
# Create entity from members
es.entity_from_dataframe(entity_id='members', dataframe=members,
                         index = 'msno', time_index = 'registration_init_time', 
                         variable_types = {'city': vtypes.Categorical, 
                                           'registered_via': vtypes.Categorical})
#Create entity from user logs
es.entity_from_dataframe(entity_id='logs', dataframe=logs,
                         index = 'logs_index', make_index = True,
                         time_index = 'date')

# Relationships (parent, child)
r_member_transactions = ft.Relationship(es['members']['msno'], es['transactions']['msno'])
r_member_logs = ft.Relationship(es['members']['msno'], es['logs']['msno'])

es.add_relationships([r_member_transactions, r_member_logs])
# Out:
# Entityset: customers
#   Entities:
#     transactions [Rows: 16351, Columns: 10]
#     members [Rows: 882, Columns: 6]
#     logs [Rows: 252022, Columns: 10]
#   Relationships:
#     transactions.msno -> members.msno
#     logs.msno -> members.msno

# %% [markdown]
# ## Feature Extraction
#
# Now that we have set up the `EntitySet` we can run the FeatureExtraction class. The `target_entity` is the `members` entity as we want to perform the aggregate functions on the `logs` and `trans` features and transform functions on `members`. We will also use a `training_window` of 3 and 6 months (`time_scope = 'monthly'`). Furthermore, we will create features using a `max_depth` of 3, meaning that we will create features _on top_ of the created features. The feature matrix generated will comprise of features that were built using data before the cutoff time as well as 3 and 6 months from the cutoff time.

# %%
# Specify aggregation primitives
agg_primitives = ['sum', 'time_since_last', 'avg_time_between', 'all', 'mode', 'num_unique', 'min', 'last', 
                  'mean', 'percent_true', 'max', 'std', 'count']
# Specify transformation primitives
trans_primitives = ['weekend', 'cum_sum', 'day', 'month', 'diff', 'time_since_previous']

# %%
from timeit import default_timer as timer

start = timer()

kkbox_mo = FeatureExtraction(es)
kkbox_mo.add_agg_primitives(agg_primitives)
kkbox_mo.add_trans_primitives(trans_primitives)
training_window = [3,6]
kkbox_mo.dfsWindow('members', 'monthly', training_window, cutoff_times, max_depth=3, chunk_size=1000)

end = timer()
print('%f seconds elapsed.'%round(end - start))
# Out:
# The aggregate primitives have been added:  sum time_since_last avg_time_between all mode num_unique min last mean percent_true max std count
# weekend is not in the available transform primitives.
# The transformative primitives have been added:  cum_sum day month diff time_since_previous
# Built 301 features
# Elapsed: 02:34 | Remaining: 00:00 | Progress: 100%|██████████| Calculated: 22/22 chunks
# 2019-04-19 04:58:19,133 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:58:19,140 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:58:19,161 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:58:19,166 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:58:19,173 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:58:19,195 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:58:20,085 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:58:20,091 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:58:20,113 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:58:20,120 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:58:20,127 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:58:20,149 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:58:21,158 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:58:21,165 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:58:21,181 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:58:21,187 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:58:21,193 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:58:21,212 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:58:22,044 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:58:22,052 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:58:22,077 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:58:22,083 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:58:22,090 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:58:22,112 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:58:23,091 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:58:23,099 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:58:23,127 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:58:23,135 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:58:23,143 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:58:23,172 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:58:24,171 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:58:24,177 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:58:24,195 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:58:24,200 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:58:24,207 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:58:24,223 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:58:25,239 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:58:25,246 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:58:25,271 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:58:25,277 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:58:25,284 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:58:25,311 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:58:26,248 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:58:26,254 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:58:26,278 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:58:26,283 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:58:26,290 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:58:26,317 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:58:27,249 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:58:27,256 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:58:27,283 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:58:27,290 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:58:27,296 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:58:27,315 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:58:28,355 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:58:28,362 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:58:28,385 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:58:28,390 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:58:28,397 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:58:28,424 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:58:29,383 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:58:29,392 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:58:29,410 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:58:29,415 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:58:29,422 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:58:29,441 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:58:30,519 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:58:30,527 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:58:30,548 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:58:30,554 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:58:30,561 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:58:30,587 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:58:31,790 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:58:31,797 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:58:31,817 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:58:31,823 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:58:31,833 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:58:31,855 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:58:33,126 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:58:33,144 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:58:33,239 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:58:33,250 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:58:33,267 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:58:33,314 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:58:34,585 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:58:34,607 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:58:34,653 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:58:34,659 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:58:34,667 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:58:34,714 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:58:36,356 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:58:36,364 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:58:36,392 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:58:36,398 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:58:36,406 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:58:36,429 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:58:37,066 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:58:37,073 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:58:37,092 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:58:37,099 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:58:37,106 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:58:37,124 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:58:38,190 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:58:38,196 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:58:38,221 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:58:38,227 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:58:38,234 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:58:38,252 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:58:38,981 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:58:38,988 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:58:39,008 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:58:39,014 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:58:39,021 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:58:39,041 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:58:40,116 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:58:40,124 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:58:40,155 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:58:40,162 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:58:40,169 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:58:40,189 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:58:41,218 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:58:41,225 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:58:41,244 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:58:41,250 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:58:41,257 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:58:41,277 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:58:42,128 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:58:42,135 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:58:42,157 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:58:42,162 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:58:42,170 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:58:42,192 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:58:43,058 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:58:43,065 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:58:43,087 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:58:43,093 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:58:43,101 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:58:43,127 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:58:43,967 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:58:43,973 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:58:43,992 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:58:43,997 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:58:44,003 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:58:44,026 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:58:44,797 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:58:44,804 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:58:44,827 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:58:44,834 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:58:44,840 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:58:44,857 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:58:45,511 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:58:45,517 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:58:45,540 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:58:45,545 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:58:45,551 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:58:45,568 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:58:46,249 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:58:46,256 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:58:46,273 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:58:46,279 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:58:46,286 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:58:46,304 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:58:47,549 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:58:47,557 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:58:47,581 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:58:47,587 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:58:47,594 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:58:47,616 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:58:48,848 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:58:48,854 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:58:48,876 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:58:48,882 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:58:48,890 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:58:48,913 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:58:50,290 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:58:50,297 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:58:50,320 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:58:50,326 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:58:50,334 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:58:50,362 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:58:51,703 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:58:51,710 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:58:51,734 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:58:51,741 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:58:51,748 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:58:51,774 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:58:53,049 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:58:53,056 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:58:53,086 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:58:53,092 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:58:53,099 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:58:53,124 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:58:54,395 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:58:54,402 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:58:54,419 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:58:54,425 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:58:54,431 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:58:54,448 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:58:55,830 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:58:55,838 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:58:55,867 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:58:55,873 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:58:55,880 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:58:55,910 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:58:57,245 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:58:57,252 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:58:57,271 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:58:57,277 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:58:57,284 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:58:57,304 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:58:58,848 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:58:58,854 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:58:58,871 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:58:58,877 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:58:58,884 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:58:58,902 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:59:00,055 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:59:00,062 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:59:00,080 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:59:00,086 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:59:00,094 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:59:00,114 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:59:01,576 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:59:01,583 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:59:01,606 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:59:01,612 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:59:01,620 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:59:01,639 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:59:03,147 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:59:03,155 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:59:03,176 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:59:03,182 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:59:03,190 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:59:03,211 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:59:04,899 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:59:04,907 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:59:04,928 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:59:04,935 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:59:04,942 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:59:04,964 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:59:06,482 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:59:06,490 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:59:06,510 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:59:06,516 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:59:06,523 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:59:06,543 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:59:08,060 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:59:08,067 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:59:08,088 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:59:08,094 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:59:08,102 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:59:08,123 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:59:09,515 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:59:09,522 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:59:09,545 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:59:09,550 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:59:09,557 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:59:09,578 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:59:10,196 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:59:10,204 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:59:10,232 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:59:10,238 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:59:10,246 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:59:10,276 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:59:11,648 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:59:11,656 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:59:11,681 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:59:11,687 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:59:11,694 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:59:11,719 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:59:12,552 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:59:12,559 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:59:12,582 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:59:12,587 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:59:12,595 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:59:12,620 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:59:13,797 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:59:13,804 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:59:13,826 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:59:13,831 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:59:13,838 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:59:13,859 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:59:14,911 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:59:14,918 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:59:14,937 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:59:14,942 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:59:14,949 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:59:14,968 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:59:15,770 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:59:15,777 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:59:15,796 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:59:15,803 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:59:15,810 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:59:15,828 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:59:16,849 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:59:16,857 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:59:16,886 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:59:16,892 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:59:16,898 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:59:16,915 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:59:17,660 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:59:17,667 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:59:17,688 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:59:17,694 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:59:17,702 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:59:17,723 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:59:18,588 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:59:18,595 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:59:18,620 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:59:18,627 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:59:18,636 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:59:18,665 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:59:19,500 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:59:19,507 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:59:19,528 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:59:19,534 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:59:19,541 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:59:19,564 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:59:20,452 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:59:20,460 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:59:20,484 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# 2019-04-19 04:59:20,490 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity members
# 2019-04-19 04:59:20,497 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity transactions
# 2019-04-19 04:59:20,515 featuretools.entityset - WARNING    Using training_window but last_time_index is not set on entity logs
# ---> 78 columns dropped due to duplicate values:
#
# 239.000000 seconds elapsed.

# %%
print("Number of features in kkbox_mo: ", len(kkbox_mo.feature_defs))
kkbox_mo.feature_defs
# Out:
# Number of features in kkbox_mo:  834
# ['city',
#  'gender',
#  'bd',
#  'registered_via',
#  'MEAN(transactions.actual_amount_paid)',
#  'LAST(logs.num_unq)',
#  'AVG_TIME_BETWEEN(logs.date)',
#  'MIN(logs.num_75)',
#  'SUM(logs.total_secs)',
#  'AVG_TIME_BETWEEN(transactions.transaction_date)',
#  'MIN(logs.num_50)',
#  'MIN(logs.total_secs)',
#  'SUM(logs.num_unq)',
#  'MONTH(registration_init_time)',
#  'LAST(logs.num_50)',
#  'PERCENT_TRUE(transactions.is_auto_renew)',
#  'LAST(transactions.plan_list_price)',
#  'MIN(transactions.plan_list_price)',
#  'STD(transactions.plan_list_price)',
#  'MEAN(logs.num_unq)',
#  'LAST(transactions.is_auto_renew)',
#  'MAX(logs.num_100)',
#  'LAST(logs.total_secs)',
#  'STD(logs.num_25)',
#  'COUNT(logs)',
#  'MEAN(logs.total_secs)',
#  'SUM(transactions.plan_list_price)',
#  'LAST(logs.num_25)',
#  'MEAN(logs.num_25)',
#  'ALL(transactions.is_auto_renew)',
#  'MAX(logs.num_75)',
#  'LAST(logs.num_75)',
#  'MAX(logs.total_secs)',
#  'STD(logs.total_secs)',
#  'MAX(logs.num_25)',
#  'SUM(transactions.actual_amount_paid)',
#  'NUM_UNIQUE(transactions.payment_method_id)',
#  'STD(logs.num_985)',
#  'COUNT(transactions)',
#  'LAST(logs.num_985)',
#  'STD(logs.num_75)',
#  'CUM_SUM(bd)',
#  'LAST(transactions.payment_method_id)',
#  'MIN(logs.num_100)',
#  'MEAN(logs.num_100)',
#  'MEAN(logs.num_75)',
#  'LAST(transactions.actual_amount_paid)',
#  'STD(logs.num_unq)',
#  'MIN(logs.num_25)',
#  'MODE(transactions.payment_method_id)',
#  'MAX(logs.num_985)',
#  'MAX(transactions.actual_amount_paid)',
#  'MAX(transactions.plan_list_price)',
#  'SUM(logs.num_50)',
#  'STD(logs.num_50)',
#  'MAX(logs.num_50)',
#  'STD(logs.num_100)',
#  'LAST(transactions.is_cancel)',
#  'SUM(logs.num_75)',
#  'DAY(registration_init_time)',
#  'MIN(transactions.payment_plan_days)',
#  'STD(transactions.payment_plan_days)',
#  'MEAN(logs.num_985)',
#  'SUM(logs.num_985)',
#  'MAX(logs.num_unq)',
#  'MAX(transactions.payment_plan_days)',
#  'PERCENT_TRUE(transactions.is_cancel)',
#  'SUM(transactions.payment_plan_days)',
#  'MIN(logs.num_unq)',
#  'MEAN(transactions.payment_plan_days)',
#  'TIME_SINCE_LAST(logs.date)',
#  'MIN(logs.num_985)',
#  'MIN(transactions.actual_amount_paid)',
#  'LAST(logs.num_100)',
#  'ALL(transactions.is_cancel)',
#  'MEAN(transactions.plan_list_price)',
#  'SUM(logs.num_100)',
#  'STD(transactions.actual_amount_paid)',
#  'MEAN(logs.num_50)',
#  'LAST(transactions.payment_plan_days)',
#  'TIME_SINCE_LAST(transactions.transaction_date)',
#  'SUM(logs.num_25)',
#  'CUM_SUM(MEAN(logs.total_secs))',
#  'CUM_SUM(MEAN(logs.num_unq))',
#  'CUM_SUM(NUM_UNIQUE(transactions.payment_method_id))',
#  'LAST(transactions.CUM_SUM(plan_list_price))',
#  'CUM_SUM(MEAN(logs.num_985))',
#  'MEAN(logs.CUM_SUM(total_secs))',
#  'CUM_SUM(MIN(logs.num_985))',
#  'LAST(transactions.MONTH(membership_expire_date))',
#  'NUM_UNIQUE(transactions.MONTH(transaction_date))',
#  'CUM_SUM(SUM(logs.total_secs))',
#  'CUM_SUM(MAX(logs.num_25))',
#  'CUM_SUM(STD(logs.num_985))',
#  'CUM_SUM(MAX(transactions.actual_amount_paid))',
#  'DAY(LAST(logs.date))',
#  'SUM(logs.CUM_SUM(num_50))',
#  'STD(transactions.CUM_SUM(actual_amount_paid))',
#  'MAX(transactions.CUM_SUM(payment_plan_days))',
#  'CUM_SUM(MIN(transactions.plan_list_price))',
#  'CUM_SUM(MAX(logs.num_75))',
#  'MEAN(transactions.CUM_SUM(payment_plan_days))',
#  'CUM_SUM(LAST(logs.total_secs))',
#  'LAST(transactions.DAY(membership_expire_date))',
#  'LAST(logs.CUM_SUM(num_100))',
#  'LAST(logs.CUM_SUM(num_unq))',
#  'CUM_SUM(STD(transactions.payment_plan_days))',
#  'CUM_SUM(SUM(transactions.plan_list_price))',
#  'MODE(transactions.DAY(membership_expire_date))',
#  'CUM_SUM(SUM(logs.num_50))',
#  'MIN(logs.CUM_SUM(num_100))',
#  'MIN(logs.CUM_SUM(num_unq))',
#  'CUM_SUM(MIN(logs.num_50))',
#  'CUM_SUM(MEAN(logs.num_50))',
#  'STD(logs.CUM_SUM(total_secs))',
#  'NUM_UNIQUE(logs.DAY(date))',
#  'NUM_UNIQUE(transactions.MONTH(membership_expire_date))',
#  'CUM_SUM(MAX(logs.num_100))',
#  'MODE(logs.DAY(date))',
#  'NUM_UNIQUE(transactions.DAY(membership_expire_date))',
#  'SUM(logs.CUM_SUM(total_secs))',
#  'MIN(transactions.CUM_SUM(actual_amount_paid))',
#  'CUM_SUM(MIN(logs.num_unq))',
#  'SUM(transactions.CUM_SUM(actual_amount_paid))',
#  'MEAN(logs.CUM_SUM(num_unq))',
#  'MEAN(transactions.CUM_SUM(plan_list_price))',
#  'CUM_SUM(STD(transactions.actual_amount_paid))',
#  'CUM_SUM(LAST(logs.num_unq))',
#  'MIN(logs.CUM_SUM(total_secs))',
#  'CUM_SUM(LAST(transactions.plan_list_price))',
#  'CUM_SUM(STD(logs.num_100))',
#  'STD(logs.CUM_SUM(num_50))',
#  'LAST(logs.CUM_SUM(num_50))',
#  'CUM_SUM(LAST(logs.num_25))',
#  'CUM_SUM(MAX(logs.total_secs))',
#  'CUM_SUM(MEAN(transactions.actual_amount_paid))',
#  'CUM_SUM(MEAN(logs.num_100))',
#  'CUM_SUM(SUM(transactions.payment_plan_days))',
#  'CUM_SUM(STD(logs.num_75))',
#  'CUM_SUM(SUM(logs.num_985))',
#  'MAX(logs.CUM_SUM(num_985))',
#  'MIN(logs.CUM_SUM(num_985))',
#  'CUM_SUM(LAST(transactions.actual_amount_paid))',
#  'CUM_SUM(MAX(transactions.plan_list_price))',
#  'MIN(transactions.CUM_SUM(plan_list_price))',
#  'SUM(transactions.CUM_SUM(payment_plan_days))',
#  'SUM(logs.CUM_SUM(num_985))',
#  'MODE(transactions.MONTH(membership_expire_date))',
#  'STD(logs.CUM_SUM(num_985))',
#  'MIN(transactions.CUM_SUM(payment_plan_days))',
#  'LAST(logs.CUM_SUM(num_75))',
#  'MEAN(transactions.CUM_SUM(actual_amount_paid))',
#  'MAX(transactions.CUM_SUM(actual_amount_paid))',
#  'CUM_SUM(TIME_SINCE_LAST(transactions.transaction_date))',
#  'CUM_SUM(STD(transactions.plan_list_price))',
#  'SUM(logs.CUM_SUM(num_100))',
#  'CUM_SUM(MAX(logs.num_985))',
#  'CUM_SUM(SUM(logs.num_unq))',
#  'CUM_SUM(MEAN(transactions.payment_plan_days))',
#  'MEAN(logs.CUM_SUM(num_25))',
#  'CUM_SUM(STD(logs.num_50))',
#  'MEAN(logs.CUM_SUM(num_50))',
#  'MODE(transactions.MONTH(transaction_date))',
#  'CUM_SUM(TIME_SINCE_LAST(logs.date))',
#  'CUM_SUM(LAST(logs.num_75))',
#  'LAST(logs.CUM_SUM(total_secs))',
#  'CUM_SUM(STD(logs.num_25))',
#  'CUM_SUM(SUM(logs.num_100))',
#  'STD(logs.CUM_SUM(num_25))',
#  'CUM_SUM(MEAN(logs.num_75))',
#  'CUM_SUM(MAX(logs.num_unq))',
#  'CUM_SUM(MAX(logs.num_50))',
#  'CUM_SUM(SUM(logs.num_25))',
#  'CUM_SUM(STD(logs.total_secs))',
#  'CUM_SUM(STD(logs.num_unq))',
#  'MIN(logs.CUM_SUM(num_50))',
#  'DAY(LAST(transactions.transaction_date))',
#  'CUM_SUM(MIN(logs.num_100))',
#  'CUM_SUM(AVG_TIME_BETWEEN(transactions.transaction_date))',
#  'SUM(logs.CUM_SUM(num_unq))',
#  'LAST(transactions.MONTH(transaction_date))',
#  'CUM_SUM(SUM(logs.num_75))',
#  'CUM_SUM(PERCENT_TRUE(transactions.is_auto_renew))',
#  'CUM_SUM(COUNT(logs))',
#  'CUM_SUM(MIN(logs.num_75))',
#  'CUM_SUM(MIN(logs.total_secs))',
#  'MIN(logs.CUM_SUM(num_75))',
#  'CUM_SUM(MEAN(transactions.plan_list_price))',
#  'STD(transactions.CUM_SUM(plan_list_price))',
#  'CUM_SUM(MEAN(logs.num_25))',
#  'STD(logs.CUM_SUM(num_75))',
#  'MODE(logs.MONTH(date))',
#  'STD(logs.CUM_SUM(num_unq))',
#  'SUM(transactions.CUM_SUM(plan_list_price))',
#  'STD(logs.CUM_SUM(num_100))',
#  'MEAN(logs.CUM_SUM(num_100))',
#  'CUM_SUM(MIN(logs.num_25))',
#  'MAX(logs.CUM_SUM(total_secs))',
#  'CUM_SUM(COUNT(transactions))',
#  'MONTH(LAST(logs.date))',
#  'SUM(logs.CUM_SUM(num_25))',
#  'CUM_SUM(SUM(transactions.actual_amount_paid))',
#  'NUM_UNIQUE(transactions.DAY(transaction_date))',
#  'CUM_SUM(AVG_TIME_BETWEEN(logs.date))',
#  'NUM_UNIQUE(logs.MONTH(date))',
#  'CUM_SUM(MAX(transactions.payment_plan_days))',
#  'CUM_SUM(LAST(transactions.payment_plan_days))',
#  'STD(transactions.CUM_SUM(payment_plan_days))',
#  'SUM(logs.CUM_SUM(num_75))',
#  'CUM_SUM(LAST(logs.num_985))',
#  'LAST(logs.CUM_SUM(num_25))',
#  'CUM_SUM(MIN(transactions.payment_plan_days))',
#  'MODE(transactions.DAY(transaction_date))',
#  'MEAN(logs.CUM_SUM(num_985))',
#  'CUM_SUM(MIN(transactions.actual_amount_paid))',
#  'CUM_SUM(PERCENT_TRUE(transactions.is_cancel))',
#  'MIN(logs.CUM_SUM(num_25))',
#  'MEAN(logs.CUM_SUM(num_75))',
#  'CUM_SUM(LAST(logs.num_50))',
#  'CUM_SUM(LAST(logs.num_100))',
#  'CUM_SUM(MIN(transactions.CUM_SUM(plan_list_price)))',
#  'CUM_SUM(LAST(transactions.CUM_SUM(actual_amount_paid)))',
#  'CUM_SUM(SUM(logs.CUM_SUM(num_25)))',
#  'CUM_SUM(MAX(transactions.CUM_SUM(payment_plan_days)))',
#  'CUM_SUM(SUM(logs.CUM_SUM(num_75)))',
#  'CUM_SUM(MAX(logs.CUM_SUM(num_75)))',
#  'CUM_SUM(MAX(logs.CUM_SUM(num_985)))',
#  'CUM_SUM(SUM(transactions.CUM_SUM(actual_amount_paid)))',
#  'CUM_SUM(NUM_UNIQUE(transactions.MONTH(transaction_date)))',
#  'CUM_SUM(MEAN(logs.CUM_SUM(num_25)))',
#  'CUM_SUM(STD(transactions.CUM_SUM(payment_plan_days)))',
#  'CUM_SUM(MIN(logs.CUM_SUM(total_secs)))',
#  'CUM_SUM(STD(logs.CUM_SUM(num_75)))',
#  'CUM_SUM(NUM_UNIQUE(logs.MONTH(date)))',
#  'CUM_SUM(MIN(transactions.CUM_SUM(actual_amount_paid)))',
#  'CUM_SUM(NUM_UNIQUE(logs.DAY(date)))',
#  'CUM_SUM(NUM_UNIQUE(transactions.DAY(transaction_date)))',
#  'CUM_SUM(STD(logs.CUM_SUM(num_25)))',
#  'CUM_SUM(STD(logs.CUM_SUM(num_985)))',
#  'CUM_SUM(MEAN(logs.CUM_SUM(num_unq)))',
#  'CUM_SUM(SUM(logs.CUM_SUM(num_unq)))',
#  'CUM_SUM(MEAN(logs.CUM_SUM(num_985)))',
#  'CUM_SUM(MAX(logs.CUM_SUM(num_unq)))',
#  'CUM_SUM(MIN(logs.CUM_SUM(num_50)))',
#  'CUM_SUM(MIN(logs.CUM_SUM(num_100)))',
#  'CUM_SUM(SUM(transactions.CUM_SUM(plan_list_price)))',
#  'CUM_SUM(NUM_UNIQUE(transactions.MONTH(membership_expire_date)))',
#  'CUM_SUM(MAX(logs.CUM_SUM(num_100)))',
#  'CUM_SUM(MIN(logs.CUM_SUM(num_25)))',
#  'CUM_SUM(MIN(transactions.CUM_SUM(payment_plan_days)))',
#  'CUM_SUM(MIN(logs.CUM_SUM(num_75)))',
#  'CUM_SUM(MEAN(transactions.CUM_SUM(plan_list_price)))',
#  'CUM_SUM(SUM(transactions.CUM_SUM(payment_plan_days)))',
#  'CUM_SUM(SUM(logs.CUM_SUM(num_100)))',
#  'CUM_SUM(STD(logs.CUM_SUM(total_secs)))',
#  'CUM_SUM(MIN(logs.CUM_SUM(num_985)))',
#  'CUM_SUM(NUM_UNIQUE(transactions.DAY(membership_expire_date)))',
#  'CUM_SUM(STD(transactions.CUM_SUM(plan_list_price)))',
#  'CUM_SUM(LAST(logs.CUM_SUM(num_50)))',
#  'CUM_SUM(MIN(logs.CUM_SUM(num_unq)))',
#  'CUM_SUM(LAST(logs.CUM_SUM(num_25)))',
#  'CUM_SUM(STD(logs.CUM_SUM(num_50)))',
#  'CUM_SUM(MEAN(logs.CUM_SUM(num_75)))',
#  'CUM_SUM(STD(logs.CUM_SUM(num_100)))',
#  'CUM_SUM(LAST(logs.CUM_SUM(total_secs)))',
#  'CUM_SUM(MEAN(logs.CUM_SUM(total_secs)))',
#  'CUM_SUM(MEAN(transactions.CUM_SUM(actual_amount_paid)))',
#  'CUM_SUM(MEAN(logs.CUM_SUM(num_100)))',
#  'CUM_SUM(MEAN(transactions.CUM_SUM(payment_plan_days)))',
#  'CUM_SUM(LAST(transactions.CUM_SUM(plan_list_price)))',
#  'CUM_SUM(MEAN(logs.CUM_SUM(num_50)))',
#  'CUM_SUM(MAX(logs.CUM_SUM(total_secs)))',
#  'CUM_SUM(STD(logs.CUM_SUM(num_unq)))',
#  'CUM_SUM(STD(transactions.CUM_SUM(actual_amount_paid)))',
#  'CUM_SUM(SUM(logs.CUM_SUM(total_secs)))',
#  'CUM_SUM(SUM(logs.CUM_SUM(num_985)))',
#  'CUM_SUM(SUM(logs.CUM_SUM(num_50)))',
#  'label',
#  'days_to_churn',
#  'churn_date',
#  'city_3mos',
#  'gender_3mos',
#  'bd_3mos',
#  'registered_via_3mos',
#  'MEAN(transactions.actual_amount_paid)_3mos',
#  'LAST(logs.num_unq)_3mos',
#  'AVG_TIME_BETWEEN(logs.date)_3mos',
#  'MIN(logs.num_75)_3mos',
#  'SUM(logs.total_secs)_3mos',
#  'AVG_TIME_BETWEEN(transactions.transaction_date)_3mos',
#  'MIN(logs.num_50)_3mos',
#  'MIN(logs.total_secs)_3mos',
#  'SUM(logs.num_unq)_3mos',
#  'MONTH(registration_init_time)_3mos',
#  'LAST(logs.num_50)_3mos',
#  'PERCENT_TRUE(transactions.is_auto_renew)_3mos',
#  'LAST(transactions.plan_list_price)_3mos',
#  'MIN(transactions.plan_list_price)_3mos',
#  'STD(transactions.plan_list_price)_3mos',
#  'MEAN(logs.num_unq)_3mos',
#  'LAST(transactions.is_auto_renew)_3mos',
#  'MAX(logs.num_100)_3mos',
#  'LAST(logs.total_secs)_3mos',
#  'STD(logs.num_25)_3mos',
#  'COUNT(logs)_3mos',
#  'MEAN(logs.total_secs)_3mos',
#  'SUM(transactions.plan_list_price)_3mos',
#  'LAST(logs.num_25)_3mos',
#  'MEAN(logs.num_25)_3mos',
#  'ALL(transactions.is_auto_renew)_3mos',
#  'MAX(logs.num_75)_3mos',
#  'LAST(logs.num_75)_3mos',
#  'MAX(logs.total_secs)_3mos',
#  'STD(logs.total_secs)_3mos',
#  'MAX(logs.num_25)_3mos',
#  'SUM(transactions.actual_amount_paid)_3mos',
#  'NUM_UNIQUE(transactions.payment_method_id)_3mos',
#  'STD(logs.num_985)_3mos',
#  'COUNT(transactions)_3mos',
#  'LAST(logs.num_985)_3mos',
#  'STD(logs.num_75)_3mos',
#  'CUM_SUM(bd)_3mos',
#  'LAST(transactions.payment_method_id)_3mos',
#  'MIN(logs.num_100)_3mos',
#  'MEAN(logs.num_100)_3mos',
#  'MEAN(logs.num_75)_3mos',
#  'LAST(transactions.actual_amount_paid)_3mos',
#  'STD(logs.num_unq)_3mos',
#  'MIN(logs.num_25)_3mos',
#  'MODE(transactions.payment_method_id)_3mos',
#  'MAX(logs.num_985)_3mos',
#  'MAX(transactions.actual_amount_paid)_3mos',
#  'MAX(transactions.plan_list_price)_3mos',
#  'SUM(logs.num_50)_3mos',
#  'STD(logs.num_50)_3mos',
#  'MAX(logs.num_50)_3mos',
#  'STD(logs.num_100)_3mos',
#  'LAST(transactions.is_cancel)_3mos',
#  'SUM(logs.num_75)_3mos',
#  'DAY(registration_init_time)_3mos',
#  'MIN(transactions.payment_plan_days)_3mos',
#  'STD(transactions.payment_plan_days)_3mos',
#  'MEAN(logs.num_985)_3mos',
#  'SUM(logs.num_985)_3mos',
#  'MAX(logs.num_unq)_3mos',
#  'MAX(transactions.payment_plan_days)_3mos',
#  'PERCENT_TRUE(transactions.is_cancel)_3mos',
#  'SUM(transactions.payment_plan_days)_3mos',
#  'MIN(logs.num_unq)_3mos',
#  'MEAN(transactions.payment_plan_days)_3mos',
#  'TIME_SINCE_LAST(logs.date)_3mos',
#  'MIN(logs.num_985)_3mos',
#  'MIN(transactions.actual_amount_paid)_3mos',
#  'LAST(logs.num_100)_3mos',
#  'ALL(transactions.is_cancel)_3mos',
#  'MEAN(transactions.plan_list_price)_3mos',
#  'SUM(logs.num_100)_3mos',
#  'STD(transactions.actual_amount_paid)_3mos',
#  'MEAN(logs.num_50)_3mos',
#  'LAST(transactions.payment_plan_days)_3mos',
#  'TIME_SINCE_LAST(transactions.transaction_date)_3mos',
#  'SUM(logs.num_25)_3mos',
#  'CUM_SUM(MEAN(logs.total_secs))_3mos',
#  'CUM_SUM(MEAN(logs.num_unq))_3mos',
#  'CUM_SUM(NUM_UNIQUE(transactions.payment_method_id))_3mos',
#  'LAST(transactions.CUM_SUM(plan_list_price))_3mos',
#  'CUM_SUM(MEAN(logs.num_985))_3mos',
#  'MEAN(logs.CUM_SUM(total_secs))_3mos',
#  'CUM_SUM(MIN(logs.num_985))_3mos',
#  'LAST(transactions.MONTH(membership_expire_date))_3mos',
#  'NUM_UNIQUE(transactions.MONTH(transaction_date))_3mos',
#  'CUM_SUM(SUM(logs.total_secs))_3mos',
#  'CUM_SUM(MAX(logs.num_25))_3mos',
#  'CUM_SUM(STD(logs.num_985))_3mos',
#  'CUM_SUM(MAX(transactions.actual_amount_paid))_3mos',
#  'DAY(LAST(logs.date))_3mos',
#  'SUM(logs.CUM_SUM(num_50))_3mos',
#  'STD(transactions.CUM_SUM(actual_amount_paid))_3mos',
#  'MAX(transactions.CUM_SUM(payment_plan_days))_3mos',
#  'CUM_SUM(MIN(transactions.plan_list_price))_3mos',
#  'CUM_SUM(MAX(logs.num_75))_3mos',
#  'MEAN(transactions.CUM_SUM(payment_plan_days))_3mos',
#  'CUM_SUM(LAST(logs.total_secs))_3mos',
#  'LAST(transactions.DAY(membership_expire_date))_3mos',
#  'LAST(logs.CUM_SUM(num_100))_3mos',
#  'LAST(logs.CUM_SUM(num_unq))_3mos',
#  'CUM_SUM(STD(transactions.payment_plan_days))_3mos',
#  'CUM_SUM(SUM(transactions.plan_list_price))_3mos',
#  'MODE(transactions.DAY(membership_expire_date))_3mos',
#  'CUM_SUM(SUM(logs.num_50))_3mos',
#  'MIN(logs.CUM_SUM(num_100))_3mos',
#  'MIN(logs.CUM_SUM(num_unq))_3mos',
#  'CUM_SUM(MIN(logs.num_50))_3mos',
#  'CUM_SUM(MEAN(logs.num_50))_3mos',
#  'STD(logs.CUM_SUM(total_secs))_3mos',
#  'NUM_UNIQUE(logs.DAY(date))_3mos',
#  'NUM_UNIQUE(transactions.MONTH(membership_expire_date))_3mos',
#  'CUM_SUM(MAX(logs.num_100))_3mos',
#  'MODE(logs.DAY(date))_3mos',
#  'NUM_UNIQUE(transactions.DAY(membership_expire_date))_3mos',
#  'SUM(logs.CUM_SUM(total_secs))_3mos',
#  'MIN(transactions.CUM_SUM(actual_amount_paid))_3mos',
#  'CUM_SUM(MIN(logs.num_unq))_3mos',
#  'SUM(transactions.CUM_SUM(actual_amount_paid))_3mos',
#  'MEAN(logs.CUM_SUM(num_unq))_3mos',
#  'MEAN(transactions.CUM_SUM(plan_list_price))_3mos',
#  'CUM_SUM(STD(transactions.actual_amount_paid))_3mos',
#  'CUM_SUM(LAST(logs.num_unq))_3mos',
#  'MIN(logs.CUM_SUM(total_secs))_3mos',
#  'CUM_SUM(LAST(transactions.plan_list_price))_3mos',
#  'CUM_SUM(STD(logs.num_100))_3mos',
#  'STD(logs.CUM_SUM(num_50))_3mos',
#  'LAST(logs.CUM_SUM(num_50))_3mos',
#  'CUM_SUM(LAST(logs.num_25))_3mos',
#  'CUM_SUM(MAX(logs.total_secs))_3mos',
#  'CUM_SUM(MEAN(transactions.actual_amount_paid))_3mos',
#  'CUM_SUM(MEAN(logs.num_100))_3mos',
#  'CUM_SUM(SUM(transactions.payment_plan_days))_3mos',
#  'CUM_SUM(STD(logs.num_75))_3mos',
#  'CUM_SUM(SUM(logs.num_985))_3mos',
#  'MAX(logs.CUM_SUM(num_985))_3mos',
#  'MIN(logs.CUM_SUM(num_985))_3mos',
#  'CUM_SUM(LAST(transactions.actual_amount_paid))_3mos',
#  'CUM_SUM(MAX(transactions.plan_list_price))_3mos',
#  'MIN(transactions.CUM_SUM(plan_list_price))_3mos',
#  'SUM(transactions.CUM_SUM(payment_plan_days))_3mos',
#  'SUM(logs.CUM_SUM(num_985))_3mos',
#  'MODE(transactions.MONTH(membership_expire_date))_3mos',
#  'STD(logs.CUM_SUM(num_985))_3mos',
#  'MIN(transactions.CUM_SUM(payment_plan_days))_3mos',
#  'LAST(logs.CUM_SUM(num_75))_3mos',
#  'MEAN(transactions.CUM_SUM(actual_amount_paid))_3mos',
#  'MAX(transactions.CUM_SUM(actual_amount_paid))_3mos',
#  'CUM_SUM(TIME_SINCE_LAST(transactions.transaction_date))_3mos',
#  'CUM_SUM(STD(transactions.plan_list_price))_3mos',
#  'SUM(logs.CUM_SUM(num_100))_3mos',
#  'CUM_SUM(MAX(logs.num_985))_3mos',
#  'CUM_SUM(SUM(logs.num_unq))_3mos',
#  'CUM_SUM(MEAN(transactions.payment_plan_days))_3mos',
#  'MEAN(logs.CUM_SUM(num_25))_3mos',
#  'CUM_SUM(STD(logs.num_50))_3mos',
#  'MEAN(logs.CUM_SUM(num_50))_3mos',
#  'MODE(transactions.MONTH(transaction_date))_3mos',
#  'CUM_SUM(TIME_SINCE_LAST(logs.date))_3mos',
#  'CUM_SUM(LAST(logs.num_75))_3mos',
#  'LAST(logs.CUM_SUM(total_secs))_3mos',
#  'CUM_SUM(STD(logs.num_25))_3mos',
#  'CUM_SUM(SUM(logs.num_100))_3mos',
#  'STD(logs.CUM_SUM(num_25))_3mos',
#  'CUM_SUM(MEAN(logs.num_75))_3mos',
#  'CUM_SUM(MAX(logs.num_unq))_3mos',
#  'CUM_SUM(MAX(logs.num_50))_3mos',
#  'CUM_SUM(SUM(logs.num_25))_3mos',
#  'CUM_SUM(STD(logs.total_secs))_3mos',
#  'CUM_SUM(STD(logs.num_unq))_3mos',
#  'MIN(logs.CUM_SUM(num_50))_3mos',
#  'DAY(LAST(transactions.transaction_date))_3mos',
#  'CUM_SUM(MIN(logs.num_100))_3mos',
#  'CUM_SUM(AVG_TIME_BETWEEN(transactions.transaction_date))_3mos',
#  'SUM(logs.CUM_SUM(num_unq))_3mos',
#  'LAST(transactions.MONTH(transaction_date))_3mos',
#  'CUM_SUM(SUM(logs.num_75))_3mos',
#  'CUM_SUM(PERCENT_TRUE(transactions.is_auto_renew))_3mos',
#  'CUM_SUM(COUNT(logs))_3mos',
#  'CUM_SUM(MIN(logs.num_75))_3mos',
#  'CUM_SUM(MIN(logs.total_secs))_3mos',
#  'MIN(logs.CUM_SUM(num_75))_3mos',
#  'CUM_SUM(MEAN(transactions.plan_list_price))_3mos',
#  'STD(transactions.CUM_SUM(plan_list_price))_3mos',
#  'CUM_SUM(MEAN(logs.num_25))_3mos',
#  'STD(logs.CUM_SUM(num_75))_3mos',
#  'MODE(logs.MONTH(date))_3mos',
#  'STD(logs.CUM_SUM(num_unq))_3mos',
#  'SUM(transactions.CUM_SUM(plan_list_price))_3mos',
#  'STD(logs.CUM_SUM(num_100))_3mos',
#  'MEAN(logs.CUM_SUM(num_100))_3mos',
#  'CUM_SUM(MIN(logs.num_25))_3mos',
#  'MAX(logs.CUM_SUM(total_secs))_3mos',
#  'CUM_SUM(COUNT(transactions))_3mos',
#  'MONTH(LAST(logs.date))_3mos',
#  'SUM(logs.CUM_SUM(num_25))_3mos',
#  'CUM_SUM(SUM(transactions.actual_amount_paid))_3mos',
#  'NUM_UNIQUE(transactions.DAY(transaction_date))_3mos',
#  'CUM_SUM(AVG_TIME_BETWEEN(logs.date))_3mos',
#  'NUM_UNIQUE(logs.MONTH(date))_3mos',
#  'CUM_SUM(MAX(transactions.payment_plan_days))_3mos',
#  'CUM_SUM(LAST(transactions.payment_plan_days))_3mos',
#  'STD(transactions.CUM_SUM(payment_plan_days))_3mos',
#  'SUM(logs.CUM_SUM(num_75))_3mos',
#  'CUM_SUM(LAST(logs.num_985))_3mos',
#  'LAST(logs.CUM_SUM(num_25))_3mos',
#  'CUM_SUM(MIN(transactions.payment_plan_days))_3mos',
#  'MODE(transactions.DAY(transaction_date))_3mos',
#  'MEAN(logs.CUM_SUM(num_985))_3mos',
#  'CUM_SUM(MIN(transactions.actual_amount_paid))_3mos',
#  'CUM_SUM(PERCENT_TRUE(transactions.is_cancel))_3mos',
#  'MIN(logs.CUM_SUM(num_25))_3mos',
#  'MEAN(logs.CUM_SUM(num_75))_3mos',
#  'CUM_SUM(LAST(logs.num_50))_3mos',
#  'CUM_SUM(LAST(logs.num_100))_3mos',
#  'CUM_SUM(MIN(transactions.CUM_SUM(plan_list_price)))_3mos',
#  'CUM_SUM(LAST(transactions.CUM_SUM(actual_amount_paid)))_3mos',
#  'CUM_SUM(SUM(logs.CUM_SUM(num_25)))_3mos',
#  'CUM_SUM(MAX(transactions.CUM_SUM(payment_plan_days)))_3mos',
#  'CUM_SUM(SUM(logs.CUM_SUM(num_75)))_3mos',
#  'CUM_SUM(MAX(logs.CUM_SUM(num_75)))_3mos',
#  'CUM_SUM(MAX(logs.CUM_SUM(num_985)))_3mos',
#  'CUM_SUM(SUM(transactions.CUM_SUM(actual_amount_paid)))_3mos',
#  'CUM_SUM(NUM_UNIQUE(transactions.MONTH(transaction_date)))_3mos',
#  'CUM_SUM(MEAN(logs.CUM_SUM(num_25)))_3mos',
#  'CUM_SUM(STD(transactions.CUM_SUM(payment_plan_days)))_3mos',
#  'CUM_SUM(MIN(logs.CUM_SUM(total_secs)))_3mos',
#  'CUM_SUM(STD(logs.CUM_SUM(num_75)))_3mos',
#  'CUM_SUM(NUM_UNIQUE(logs.MONTH(date)))_3mos',
#  'CUM_SUM(MIN(transactions.CUM_SUM(actual_amount_paid)))_3mos',
#  'CUM_SUM(NUM_UNIQUE(logs.DAY(date)))_3mos',
#  'CUM_SUM(NUM_UNIQUE(transactions.DAY(transaction_date)))_3mos',
#  'CUM_SUM(STD(logs.CUM_SUM(num_25)))_3mos',
#  'CUM_SUM(STD(logs.CUM_SUM(num_985)))_3mos',
#  'CUM_SUM(MEAN(logs.CUM_SUM(num_unq)))_3mos',
#  'CUM_SUM(SUM(logs.CUM_SUM(num_unq)))_3mos',
#  'CUM_SUM(MEAN(logs.CUM_SUM(num_985)))_3mos',
#  'CUM_SUM(MAX(logs.CUM_SUM(num_unq)))_3mos',
#  'CUM_SUM(MIN(logs.CUM_SUM(num_50)))_3mos',
#  'CUM_SUM(MIN(logs.CUM_SUM(num_100)))_3mos',
#  'CUM_SUM(SUM(transactions.CUM_SUM(plan_list_price)))_3mos',
#  'CUM_SUM(NUM_UNIQUE(transactions.MONTH(membership_expire_date)))_3mos',
#  'CUM_SUM(MAX(logs.CUM_SUM(num_100)))_3mos',
#  'CUM_SUM(MIN(logs.CUM_SUM(num_25)))_3mos',
#  'CUM_SUM(MIN(transactions.CUM_SUM(payment_plan_days)))_3mos',
#  'CUM_SUM(MIN(logs.CUM_SUM(num_75)))_3mos',
#  'CUM_SUM(MEAN(transactions.CUM_SUM(plan_list_price)))_3mos',
#  'CUM_SUM(SUM(transactions.CUM_SUM(payment_plan_days)))_3mos',
#  'CUM_SUM(SUM(logs.CUM_SUM(num_100)))_3mos',
#  'CUM_SUM(STD(logs.CUM_SUM(total_secs)))_3mos',
#  'CUM_SUM(MIN(logs.CUM_SUM(num_985)))_3mos',
#  'CUM_SUM(NUM_UNIQUE(transactions.DAY(membership_expire_date)))_3mos',
#  'CUM_SUM(STD(transactions.CUM_SUM(plan_list_price)))_3mos',
#  'CUM_SUM(LAST(logs.CUM_SUM(num_50)))_3mos',
#  'CUM_SUM(MIN(logs.CUM_SUM(num_unq)))_3mos',
#  'CUM_SUM(LAST(logs.CUM_SUM(num_25)))_3mos',
#  'CUM_SUM(STD(logs.CUM_SUM(num_50)))_3mos',
#  'CUM_SUM(MEAN(logs.CUM_SUM(num_75)))_3mos',
#  'CUM_SUM(STD(logs.CUM_SUM(num_100)))_3mos',
#  'CUM_SUM(LAST(logs.CUM_SUM(total_secs)))_3mos',
#  'CUM_SUM(MEAN(logs.CUM_SUM(total_secs)))_3mos',
#  'CUM_SUM(MEAN(transactions.CUM_SUM(actual_amount_paid)))_3mos',
#  'CUM_SUM(MEAN(logs.CUM_SUM(num_100)))_3mos',
#  'CUM_SUM(MEAN(transactions.CUM_SUM(payment_plan_days)))_3mos',
#  'CUM_SUM(LAST(transactions.CUM_SUM(plan_list_price)))_3mos',
#  'CUM_SUM(MEAN(logs.CUM_SUM(num_50)))_3mos',
#  'CUM_SUM(MAX(logs.CUM_SUM(total_secs)))_3mos',
#  'CUM_SUM(STD(logs.CUM_SUM(num_unq)))_3mos',
#  'CUM_SUM(STD(transactions.CUM_SUM(actual_amount_paid)))_3mos',
#  'CUM_SUM(SUM(logs.CUM_SUM(total_secs)))_3mos',
#  'CUM_SUM(SUM(logs.CUM_SUM(num_985)))_3mos',
#  'CUM_SUM(SUM(logs.CUM_SUM(num_50)))_3mos',
#  'city_6mos',
#  'gender_6mos',
#  'bd_6mos',
#  'registered_via_6mos',
#  'MEAN(transactions.actual_amount_paid)_6mos',
#  'LAST(logs.num_unq)_6mos',
#  'AVG_TIME_BETWEEN(logs.date)_6mos',
#  'MIN(logs.num_75)_6mos',
#  'SUM(logs.total_secs)_6mos',
#  'AVG_TIME_BETWEEN(transactions.transaction_date)_6mos',
#  'MIN(logs.num_50)_6mos',
#  'MIN(logs.total_secs)_6mos',
#  'SUM(logs.num_unq)_6mos',
#  'MONTH(registration_init_time)_6mos',
#  'LAST(logs.num_50)_6mos',
#  'PERCENT_TRUE(transactions.is_auto_renew)_6mos',
#  'LAST(transactions.plan_list_price)_6mos',
#  'MIN(transactions.plan_list_price)_6mos',
#  'STD(transactions.plan_list_price)_6mos',
#  'MEAN(logs.num_unq)_6mos',
#  'LAST(transactions.is_auto_renew)_6mos',
#  'MAX(logs.num_100)_6mos',
#  'LAST(logs.total_secs)_6mos',
#  'STD(logs.num_25)_6mos',
#  'COUNT(logs)_6mos',
#  'MEAN(logs.total_secs)_6mos',
#  'SUM(transactions.plan_list_price)_6mos',
#  'LAST(logs.num_25)_6mos',
#  'MEAN(logs.num_25)_6mos',
#  'ALL(transactions.is_auto_renew)_6mos',
#  'MAX(logs.num_75)_6mos',
#  'LAST(logs.num_75)_6mos',
#  'MAX(logs.total_secs)_6mos',
#  'STD(logs.total_secs)_6mos',
#  'MAX(logs.num_25)_6mos',
#  'SUM(transactions.actual_amount_paid)_6mos',
#  'NUM_UNIQUE(transactions.payment_method_id)_6mos',
#  'STD(logs.num_985)_6mos',
#  'COUNT(transactions)_6mos',
#  'LAST(logs.num_985)_6mos',
#  'STD(logs.num_75)_6mos',
#  'CUM_SUM(bd)_6mos',
#  'LAST(transactions.payment_method_id)_6mos',
#  'MIN(logs.num_100)_6mos',
#  'MEAN(logs.num_100)_6mos',
#  'MEAN(logs.num_75)_6mos',
#  'LAST(transactions.actual_amount_paid)_6mos',
#  'STD(logs.num_unq)_6mos',
#  'MIN(logs.num_25)_6mos',
#  'MODE(transactions.payment_method_id)_6mos',
#  'MAX(logs.num_985)_6mos',
#  'MAX(transactions.actual_amount_paid)_6mos',
#  'MAX(transactions.plan_list_price)_6mos',
#  'SUM(logs.num_50)_6mos',
#  'STD(logs.num_50)_6mos',
#  'MAX(logs.num_50)_6mos',
#  'STD(logs.num_100)_6mos',
#  'LAST(transactions.is_cancel)_6mos',
#  'SUM(logs.num_75)_6mos',
#  'DAY(registration_init_time)_6mos',
#  'MIN(transactions.payment_plan_days)_6mos',
#  'STD(transactions.payment_plan_days)_6mos',
#  'MEAN(logs.num_985)_6mos',
#  'SUM(logs.num_985)_6mos',
#  'MAX(logs.num_unq)_6mos',
#  'MAX(transactions.payment_plan_days)_6mos',
#  'PERCENT_TRUE(transactions.is_cancel)_6mos',
#  'SUM(transactions.payment_plan_days)_6mos',
#  'MIN(logs.num_unq)_6mos',
#  'MEAN(transactions.payment_plan_days)_6mos',
#  'TIME_SINCE_LAST(logs.date)_6mos',
#  'MIN(logs.num_985)_6mos',
#  'MIN(transactions.actual_amount_paid)_6mos',
#  'LAST(logs.num_100)_6mos',
#  'ALL(transactions.is_cancel)_6mos',
#  'MEAN(transactions.plan_list_price)_6mos',
#  'SUM(logs.num_100)_6mos',
#  'STD(transactions.actual_amount_paid)_6mos',
#  'MEAN(logs.num_50)_6mos',
#  'LAST(transactions.payment_plan_days)_6mos',
#  'TIME_SINCE_LAST(transactions.transaction_date)_6mos',
#  'SUM(logs.num_25)_6mos',
#  'CUM_SUM(MEAN(logs.total_secs))_6mos',
#  'CUM_SUM(MEAN(logs.num_unq))_6mos',
#  'CUM_SUM(NUM_UNIQUE(transactions.payment_method_id))_6mos',
#  'LAST(transactions.CUM_SUM(plan_list_price))_6mos',
#  'CUM_SUM(MEAN(logs.num_985))_6mos',
#  'MEAN(logs.CUM_SUM(total_secs))_6mos',
#  'CUM_SUM(MIN(logs.num_985))_6mos',
#  'LAST(transactions.MONTH(membership_expire_date))_6mos',
#  'NUM_UNIQUE(transactions.MONTH(transaction_date))_6mos',
#  'CUM_SUM(SUM(logs.total_secs))_6mos',
#  'CUM_SUM(MAX(logs.num_25))_6mos',
#  'CUM_SUM(STD(logs.num_985))_6mos',
#  'CUM_SUM(MAX(transactions.actual_amount_paid))_6mos',
#  'DAY(LAST(logs.date))_6mos',
#  'SUM(logs.CUM_SUM(num_50))_6mos',
#  'STD(transactions.CUM_SUM(actual_amount_paid))_6mos',
#  'MAX(transactions.CUM_SUM(payment_plan_days))_6mos',
#  'CUM_SUM(MIN(transactions.plan_list_price))_6mos',
#  'CUM_SUM(MAX(logs.num_75))_6mos',
#  'MEAN(transactions.CUM_SUM(payment_plan_days))_6mos',
#  'CUM_SUM(LAST(logs.total_secs))_6mos',
#  'LAST(transactions.DAY(membership_expire_date))_6mos',
#  'LAST(logs.CUM_SUM(num_100))_6mos',
#  'LAST(logs.CUM_SUM(num_unq))_6mos',
#  'CUM_SUM(STD(transactions.payment_plan_days))_6mos',
#  'CUM_SUM(SUM(transactions.plan_list_price))_6mos',
#  'MODE(transactions.DAY(membership_expire_date))_6mos',
#  'CUM_SUM(SUM(logs.num_50))_6mos',
#  'MIN(logs.CUM_SUM(num_100))_6mos',
#  'MIN(logs.CUM_SUM(num_unq))_6mos',
#  'CUM_SUM(MIN(logs.num_50))_6mos',
#  'CUM_SUM(MEAN(logs.num_50))_6mos',
#  'STD(logs.CUM_SUM(total_secs))_6mos',
#  'NUM_UNIQUE(logs.DAY(date))_6mos',
#  'NUM_UNIQUE(transactions.MONTH(membership_expire_date))_6mos',
#  'CUM_SUM(MAX(logs.num_100))_6mos',
#  'MODE(logs.DAY(date))_6mos',
#  'NUM_UNIQUE(transactions.DAY(membership_expire_date))_6mos',
#  'SUM(logs.CUM_SUM(total_secs))_6mos',
#  'MIN(transactions.CUM_SUM(actual_amount_paid))_6mos',
#  'CUM_SUM(MIN(logs.num_unq))_6mos',
#  'SUM(transactions.CUM_SUM(actual_amount_paid))_6mos',
#  'MEAN(logs.CUM_SUM(num_unq))_6mos',
#  'MEAN(transactions.CUM_SUM(plan_list_price))_6mos',
#  'CUM_SUM(STD(transactions.actual_amount_paid))_6mos',
#  'CUM_SUM(LAST(logs.num_unq))_6mos',
#  'MIN(logs.CUM_SUM(total_secs))_6mos',
#  'CUM_SUM(LAST(transactions.plan_list_price))_6mos',
#  'CUM_SUM(STD(logs.num_100))_6mos',
#  'STD(logs.CUM_SUM(num_50))_6mos',
#  'LAST(logs.CUM_SUM(num_50))_6mos',
#  'CUM_SUM(LAST(logs.num_25))_6mos',
#  'CUM_SUM(MAX(logs.total_secs))_6mos',
#  'CUM_SUM(MEAN(transactions.actual_amount_paid))_6mos',
#  'CUM_SUM(MEAN(logs.num_100))_6mos',
#  'CUM_SUM(SUM(transactions.payment_plan_days))_6mos',
#  'CUM_SUM(STD(logs.num_75))_6mos',
#  'CUM_SUM(SUM(logs.num_985))_6mos',
#  'MAX(logs.CUM_SUM(num_985))_6mos',
#  'MIN(logs.CUM_SUM(num_985))_6mos',
#  'CUM_SUM(LAST(transactions.actual_amount_paid))_6mos',
#  'CUM_SUM(MAX(transactions.plan_list_price))_6mos',
#  'MIN(transactions.CUM_SUM(plan_list_price))_6mos',
#  'SUM(transactions.CUM_SUM(payment_plan_days))_6mos',
#  'SUM(logs.CUM_SUM(num_985))_6mos',
#  'MODE(transactions.MONTH(membership_expire_date))_6mos',
#  'STD(logs.CUM_SUM(num_985))_6mos',
#  'MIN(transactions.CUM_SUM(payment_plan_days))_6mos',
#  'LAST(logs.CUM_SUM(num_75))_6mos',
#  'MEAN(transactions.CUM_SUM(actual_amount_paid))_6mos',
#  'MAX(transactions.CUM_SUM(actual_amount_paid))_6mos',
#  'CUM_SUM(TIME_SINCE_LAST(transactions.transaction_date))_6mos',
#  'CUM_SUM(STD(transactions.plan_list_price))_6mos',
#  'SUM(logs.CUM_SUM(num_100))_6mos',
#  'CUM_SUM(MAX(logs.num_985))_6mos',
#  'CUM_SUM(SUM(logs.num_unq))_6mos',
#  'CUM_SUM(MEAN(transactions.payment_plan_days))_6mos',
#  'MEAN(logs.CUM_SUM(num_25))_6mos',
#  'CUM_SUM(STD(logs.num_50))_6mos',
#  'MEAN(logs.CUM_SUM(num_50))_6mos',
#  'MODE(transactions.MONTH(transaction_date))_6mos',
#  'CUM_SUM(TIME_SINCE_LAST(logs.date))_6mos',
#  'CUM_SUM(LAST(logs.num_75))_6mos',
#  'LAST(logs.CUM_SUM(total_secs))_6mos',
#  'CUM_SUM(STD(logs.num_25))_6mos',
#  'CUM_SUM(SUM(logs.num_100))_6mos',
#  'STD(logs.CUM_SUM(num_25))_6mos',
#  'CUM_SUM(MEAN(logs.num_75))_6mos',
#  'CUM_SUM(MAX(logs.num_unq))_6mos',
#  'CUM_SUM(MAX(logs.num_50))_6mos',
#  'CUM_SUM(SUM(logs.num_25))_6mos',
#  'CUM_SUM(STD(logs.total_secs))_6mos',
#  'CUM_SUM(STD(logs.num_unq))_6mos',
#  'MIN(logs.CUM_SUM(num_50))_6mos',
#  'DAY(LAST(transactions.transaction_date))_6mos',
#  'CUM_SUM(MIN(logs.num_100))_6mos',
#  'CUM_SUM(AVG_TIME_BETWEEN(transactions.transaction_date))_6mos',
#  'SUM(logs.CUM_SUM(num_unq))_6mos',
#  'LAST(transactions.MONTH(transaction_date))_6mos',
#  'CUM_SUM(SUM(logs.num_75))_6mos',
#  'CUM_SUM(PERCENT_TRUE(transactions.is_auto_renew))_6mos',
#  'CUM_SUM(COUNT(logs))_6mos',
#  'CUM_SUM(MIN(logs.num_75))_6mos',
#  'CUM_SUM(MIN(logs.total_secs))_6mos',
#  'MIN(logs.CUM_SUM(num_75))_6mos',
#  'CUM_SUM(MEAN(transactions.plan_list_price))_6mos',
#  'STD(transactions.CUM_SUM(plan_list_price))_6mos',
#  'CUM_SUM(MEAN(logs.num_25))_6mos',
#  'STD(logs.CUM_SUM(num_75))_6mos',
#  'MODE(logs.MONTH(date))_6mos',
#  'STD(logs.CUM_SUM(num_unq))_6mos',
#  'SUM(transactions.CUM_SUM(plan_list_price))_6mos',
#  'STD(logs.CUM_SUM(num_100))_6mos',
#  'MEAN(logs.CUM_SUM(num_100))_6mos',
#  'CUM_SUM(MIN(logs.num_25))_6mos',
#  'MAX(logs.CUM_SUM(total_secs))_6mos',
#  'CUM_SUM(COUNT(transactions))_6mos',
#  'MONTH(LAST(logs.date))_6mos',
#  'SUM(logs.CUM_SUM(num_25))_6mos',
#  'CUM_SUM(SUM(transactions.actual_amount_paid))_6mos',
#  'NUM_UNIQUE(transactions.DAY(transaction_date))_6mos',
#  'CUM_SUM(AVG_TIME_BETWEEN(logs.date))_6mos',
#  'NUM_UNIQUE(logs.MONTH(date))_6mos',
#  'CUM_SUM(MAX(transactions.payment_plan_days))_6mos',
#  'CUM_SUM(LAST(transactions.payment_plan_days))_6mos',
#  'STD(transactions.CUM_SUM(payment_plan_days))_6mos',
#  'SUM(logs.CUM_SUM(num_75))_6mos',
#  'CUM_SUM(LAST(logs.num_985))_6mos',
#  'LAST(logs.CUM_SUM(num_25))_6mos',
#  'CUM_SUM(MIN(transactions.payment_plan_days))_6mos',
#  'MODE(transactions.DAY(transaction_date))_6mos',
#  'MEAN(logs.CUM_SUM(num_985))_6mos',
#  'CUM_SUM(MIN(transactions.actual_amount_paid))_6mos',
#  'CUM_SUM(PERCENT_TRUE(transactions.is_cancel))_6mos',
#  'MIN(logs.CUM_SUM(num_25))_6mos',
#  'MEAN(logs.CUM_SUM(num_75))_6mos',
#  'CUM_SUM(LAST(logs.num_50))_6mos',
#  'CUM_SUM(LAST(logs.num_100))_6mos',
#  'CUM_SUM(MIN(transactions.CUM_SUM(plan_list_price)))_6mos',
#  'CUM_SUM(LAST(transactions.CUM_SUM(actual_amount_paid)))_6mos',
#  'CUM_SUM(SUM(logs.CUM_SUM(num_25)))_6mos',
#  'CUM_SUM(MAX(transactions.CUM_SUM(payment_plan_days)))_6mos',
#  'CUM_SUM(SUM(logs.CUM_SUM(num_75)))_6mos',
#  'CUM_SUM(MAX(logs.CUM_SUM(num_75)))_6mos',
#  'CUM_SUM(MAX(logs.CUM_SUM(num_985)))_6mos',
#  'CUM_SUM(SUM(transactions.CUM_SUM(actual_amount_paid)))_6mos',
#  'CUM_SUM(NUM_UNIQUE(transactions.MONTH(transaction_date)))_6mos',
#  'CUM_SUM(MEAN(logs.CUM_SUM(num_25)))_6mos',
#  'CUM_SUM(STD(transactions.CUM_SUM(payment_plan_days)))_6mos',
#  'CUM_SUM(MIN(logs.CUM_SUM(total_secs)))_6mos',
#  'CUM_SUM(STD(logs.CUM_SUM(num_75)))_6mos',
#  'CUM_SUM(NUM_UNIQUE(logs.MONTH(date)))_6mos',
#  'CUM_SUM(MIN(transactions.CUM_SUM(actual_amount_paid)))_6mos',
#  'CUM_SUM(NUM_UNIQUE(logs.DAY(date)))_6mos',
#  'CUM_SUM(NUM_UNIQUE(transactions.DAY(transaction_date)))_6mos',
#  'CUM_SUM(STD(logs.CUM_SUM(num_25)))_6mos',
#  'CUM_SUM(STD(logs.CUM_SUM(num_985)))_6mos',
#  'CUM_SUM(MEAN(logs.CUM_SUM(num_unq)))_6mos',
#  'CUM_SUM(SUM(logs.CUM_SUM(num_unq)))_6mos',
#  'CUM_SUM(MEAN(logs.CUM_SUM(num_985)))_6mos',
#  'CUM_SUM(MAX(logs.CUM_SUM(num_unq)))_6mos',
#  'CUM_SUM(MIN(logs.CUM_SUM(num_50)))_6mos',
#  'CUM_SUM(MIN(logs.CUM_SUM(num_100)))_6mos',
#  'CUM_SUM(SUM(transactions.CUM_SUM(plan_list_price)))_6mos',
#  'CUM_SUM(NUM_UNIQUE(transactions.MONTH(membership_expire_date)))_6mos',
#  'CUM_SUM(MAX(logs.CUM_SUM(num_100)))_6mos',
#  'CUM_SUM(MIN(logs.CUM_SUM(num_25)))_6mos',
#  'CUM_SUM(MIN(transactions.CUM_SUM(payment_plan_days)))_6mos',
#  'CUM_SUM(MIN(logs.CUM_SUM(num_75)))_6mos',
#  'CUM_SUM(MEAN(transactions.CUM_SUM(plan_list_price)))_6mos',
#  'CUM_SUM(SUM(transactions.CUM_SUM(payment_plan_days)))_6mos',
#  'CUM_SUM(SUM(logs.CUM_SUM(num_100)))_6mos',
#  'CUM_SUM(STD(logs.CUM_SUM(total_secs)))_6mos',
#  'CUM_SUM(MIN(logs.CUM_SUM(num_985)))_6mos',
#  'CUM_SUM(NUM_UNIQUE(transactions.DAY(membership_expire_date)))_6mos',
#  'CUM_SUM(STD(transactions.CUM_SUM(plan_list_price)))_6mos',
#  'CUM_SUM(LAST(logs.CUM_SUM(num_50)))_6mos',
#  'CUM_SUM(MIN(logs.CUM_SUM(num_unq)))_6mos',
#  'CUM_SUM(LAST(logs.CUM_SUM(num_25)))_6mos',
#  'CUM_SUM(STD(logs.CUM_SUM(num_50)))_6mos',
#  'CUM_SUM(MEAN(logs.CUM_SUM(num_75)))_6mos',
#  'CUM_SUM(STD(logs.CUM_SUM(num_100)))_6mos',
#  'CUM_SUM(LAST(logs.CUM_SUM(total_secs)))_6mos',
#  'CUM_SUM(MEAN(logs.CUM_SUM(total_secs)))_6mos',
#  'CUM_SUM(MEAN(transactions.CUM_SUM(actual_amount_paid)))_6mos',
#  'CUM_SUM(MEAN(logs.CUM_SUM(num_100)))_6mos',
#  'CUM_SUM(MEAN(transactions.CUM_SUM(payment_plan_days)))_6mos',
#  'CUM_SUM(LAST(transactions.CUM_SUM(plan_list_price)))_6mos',
#  'CUM_SUM(MEAN(logs.CUM_SUM(num_50)))_6mos',
#  'CUM_SUM(MAX(logs.CUM_SUM(total_secs)))_6mos',
#  'CUM_SUM(STD(logs.CUM_SUM(num_unq)))_6mos',
#  'CUM_SUM(STD(transactions.CUM_SUM(actual_amount_paid)))_6mos',
#  'CUM_SUM(SUM(logs.CUM_SUM(total_secs)))_6mos',
#  'CUM_SUM(SUM(logs.CUM_SUM(num_985)))_6mos',
#  'CUM_SUM(SUM(logs.CUM_SUM(num_50)))_6mos']

# %%
kkbox_mo.df.head(5)
# Out:
#                                                          city gender    bd  \
# msno                                         time
# +6KodETinDioAsOrJjj1UH425xG3uM6N/bd49J15How= 2015-01-01   1.0    NaN   0.0
# +WiZkfIp5sDsf0xZvBnR2j6Kxi1u2k0t0mJBJqhQIJo= 2015-01-01  13.0   male  25.0
# +eELJ1gSSkwJItUOLgavd0hFy/TLj0RVrcaPgQunOPM= 2015-01-01  14.0    NaN   0.0
# +s3jJdEWKI0aVm/aTtJjbl1/6m9T+Fdshe1opAtZTy8= 2015-01-01   1.0    NaN   0.0
# /OrkK+agRQCMhB2GK3KctomRLGCQuWxUqw9ml1eQNog= 2015-01-01  11.0   male  22.0
#
#                                                          registered_via  \
# msno                                         time
# +6KodETinDioAsOrJjj1UH425xG3uM6N/bd49J15How= 2015-01-01             7.0
# +WiZkfIp5sDsf0xZvBnR2j6Kxi1u2k0t0mJBJqhQIJo= 2015-01-01             9.0
# +eELJ1gSSkwJItUOLgavd0hFy/TLj0RVrcaPgQunOPM= 2015-01-01             9.0
# +s3jJdEWKI0aVm/aTtJjbl1/6m9T+Fdshe1opAtZTy8= 2015-01-01             7.0
# /OrkK+agRQCMhB2GK3KctomRLGCQuWxUqw9ml1eQNog= 2015-01-01             9.0
#
#                                                          MEAN(transactions.actual_amount_paid)  \
# msno                                         time
# +6KodETinDioAsOrJjj1UH425xG3uM6N/bd49J15How= 2015-01-01                                    NaN
# +WiZkfIp5sDsf0xZvBnR2j6Kxi1u2k0t0mJBJqhQIJo= 2015-01-01                                    NaN
# +eELJ1gSSkwJItUOLgavd0hFy/TLj0RVrcaPgQunOPM= 2015-01-01                                    NaN
# +s3jJdEWKI0aVm/aTtJjbl1/6m9T+Fdshe1opAtZTy8= 2015-01-01                                    NaN
# /OrkK+agRQCMhB2GK3KctomRLGCQuWxUqw9ml1eQNog= 2015-01-01                                    NaN
#
#                                                          LAST(logs.num_unq)  \
# msno                                         time
# +6KodETinDioAsOrJjj1UH425xG3uM6N/bd49J15How= 2015-01-01                 NaN
# +WiZkfIp5sDsf0xZvBnR2j6Kxi1u2k0t0mJBJqhQIJo= 2015-01-01                17.0
# +eELJ1gSSkwJItUOLgavd0hFy/TLj0RVrcaPgQunOPM= 2015-01-01                 NaN
# +s3jJdEWKI0aVm/aTtJjbl1/6m9T+Fdshe1opAtZTy8= 2015-01-01                 NaN
# /OrkK+agRQCMhB2GK3KctomRLGCQuWxUqw9ml1eQNog= 2015-01-01                 NaN
#
#                                                          AVG_TIME_BETWEEN(logs.date)  \
# msno                                         time
# +6KodETinDioAsOrJjj1UH425xG3uM6N/bd49J15How= 2015-01-01                          NaN
# +WiZkfIp5sDsf0xZvBnR2j6Kxi1u2k0t0mJBJqhQIJo= 2015-01-01                          NaN
# +eELJ1gSSkwJItUOLgavd0hFy/TLj0RVrcaPgQunOPM= 2015-01-01                          NaN
# +s3jJdEWKI0aVm/aTtJjbl1/6m9T+Fdshe1opAtZTy8= 2015-01-01                          NaN
# /OrkK+agRQCMhB2GK3KctomRLGCQuWxUqw9ml1eQNog= 2015-01-01                          NaN
#
#                                                          MIN(logs.num_75)  \
# msno                                         time
# +6KodETinDioAsOrJjj1UH425xG3uM6N/bd49J15How= 2015-01-01               NaN
# +WiZkfIp5sDsf0xZvBnR2j6Kxi1u2k0t0mJBJqhQIJo= 2015-01-01               1.0
# +eELJ1gSSkwJItUOLgavd0hFy/TLj0RVrcaPgQunOPM= 2015-01-01               NaN
# +s3jJdEWKI0aVm/aTtJjbl1/6m9T+Fdshe1opAtZTy8= 2015-01-01               NaN
# /OrkK+agRQCMhB2GK3KctomRLGCQuWxUqw9ml1eQNog= 2015-01-01               NaN
#
#                                                          SUM(logs.total_secs)  \
# msno                                         time
# +6KodETinDioAsOrJjj1UH425xG3uM6N/bd49J15How= 2015-01-01                 0.000
# +WiZkfIp5sDsf0xZvBnR2j6Kxi1u2k0t0mJBJqhQIJo= 2015-01-01              2106.478
# +eELJ1gSSkwJItUOLgavd0hFy/TLj0RVrcaPgQunOPM= 2015-01-01                 0.000
# +s3jJdEWKI0aVm/aTtJjbl1/6m9T+Fdshe1opAtZTy8= 2015-01-01                 0.000
# /OrkK+agRQCMhB2GK3KctomRLGCQuWxUqw9ml1eQNog= 2015-01-01                 0.000
#
#                                                          AVG_TIME_BETWEEN(transactions.transaction_date)  \
# msno                                         time
# +6KodETinDioAsOrJjj1UH425xG3uM6N/bd49J15How= 2015-01-01                                              NaN
# +WiZkfIp5sDsf0xZvBnR2j6Kxi1u2k0t0mJBJqhQIJo= 2015-01-01                                              NaN
# +eELJ1gSSkwJItUOLgavd0hFy/TLj0RVrcaPgQunOPM= 2015-01-01                                              NaN
# +s3jJdEWKI0aVm/aTtJjbl1/6m9T+Fdshe1opAtZTy8= 2015-01-01                                              NaN
# /OrkK+agRQCMhB2GK3KctomRLGCQuWxUqw9ml1eQNog= 2015-01-01                                              NaN
#
#                                                                           ...                     \
# msno                                         time                         ...
# +6KodETinDioAsOrJjj1UH425xG3uM6N/bd49J15How= 2015-01-01                   ...
# +WiZkfIp5sDsf0xZvBnR2j6Kxi1u2k0t0mJBJqhQIJo= 2015-01-01                   ...
# +eELJ1gSSkwJItUOLgavd0hFy/TLj0RVrcaPgQunOPM= 2015-01-01                   ...
# +s3jJdEWKI0aVm/aTtJjbl1/6m9T+Fdshe1opAtZTy8= 2015-01-01                   ...
# /OrkK+agRQCMhB2GK3KctomRLGCQuWxUqw9ml1eQNog= 2015-01-01                   ...
#
#                                                          CUM_SUM(MEAN(logs.CUM_SUM(num_100)))_6mos  \
# msno                                         time
# +6KodETinDioAsOrJjj1UH425xG3uM6N/bd49J15How= 2015-01-01                                        NaN
# +WiZkfIp5sDsf0xZvBnR2j6Kxi1u2k0t0mJBJqhQIJo= 2015-01-01                                        NaN
# +eELJ1gSSkwJItUOLgavd0hFy/TLj0RVrcaPgQunOPM= 2015-01-01                                        NaN
# +s3jJdEWKI0aVm/aTtJjbl1/6m9T+Fdshe1opAtZTy8= 2015-01-01                                        NaN
# /OrkK+agRQCMhB2GK3KctomRLGCQuWxUqw9ml1eQNog= 2015-01-01                                        NaN
#
#                                                          CUM_SUM(MEAN(transactions.CUM_SUM(payment_plan_days)))_6mos  \
# msno                                         time
# +6KodETinDioAsOrJjj1UH425xG3uM6N/bd49J15How= 2015-01-01                                                NaN
# +WiZkfIp5sDsf0xZvBnR2j6Kxi1u2k0t0mJBJqhQIJo= 2015-01-01                                                NaN
# +eELJ1gSSkwJItUOLgavd0hFy/TLj0RVrcaPgQunOPM= 2015-01-01                                                NaN
# +s3jJdEWKI0aVm/aTtJjbl1/6m9T+Fdshe1opAtZTy8= 2015-01-01                                                NaN
# /OrkK+agRQCMhB2GK3KctomRLGCQuWxUqw9ml1eQNog= 2015-01-01                                                NaN
#
#                                                          CUM_SUM(LAST(transactions.CUM_SUM(plan_list_price)))_6mos  \
# msno                                         time
# +6KodETinDioAsOrJjj1UH425xG3uM6N/bd49J15How= 2015-01-01                                                NaN
# +WiZkfIp5sDsf0xZvBnR2j6Kxi1u2k0t0mJBJqhQIJo= 2015-01-01                                                NaN
# +eELJ1gSSkwJItUOLgavd0hFy/TLj0RVrcaPgQunOPM= 2015-01-01                                                NaN
# +s3jJdEWKI0aVm/aTtJjbl1/6m9T+Fdshe1opAtZTy8= 2015-01-01                                                NaN
# /OrkK+agRQCMhB2GK3KctomRLGCQuWxUqw9ml1eQNog= 2015-01-01                                                NaN
#
#                                                          CUM_SUM(MEAN(logs.CUM_SUM(num_50)))_6mos  \
# msno                                         time
# +6KodETinDioAsOrJjj1UH425xG3uM6N/bd49J15How= 2015-01-01                                       NaN
# +WiZkfIp5sDsf0xZvBnR2j6Kxi1u2k0t0mJBJqhQIJo= 2015-01-01                                       NaN
# +eELJ1gSSkwJItUOLgavd0hFy/TLj0RVrcaPgQunOPM= 2015-01-01                                       NaN
# +s3jJdEWKI0aVm/aTtJjbl1/6m9T+Fdshe1opAtZTy8= 2015-01-01                                       NaN
# /OrkK+agRQCMhB2GK3KctomRLGCQuWxUqw9ml1eQNog= 2015-01-01                                       NaN
#
#                                                          CUM_SUM(MAX(logs.CUM_SUM(total_secs)))_6mos  \
# msno                                         time
# +6KodETinDioAsOrJjj1UH425xG3uM6N/bd49J15How= 2015-01-01                                          NaN
# +WiZkfIp5sDsf0xZvBnR2j6Kxi1u2k0t0mJBJqhQIJo= 2015-01-01                                          NaN
# +eELJ1gSSkwJItUOLgavd0hFy/TLj0RVrcaPgQunOPM= 2015-01-01                                          NaN
# +s3jJdEWKI0aVm/aTtJjbl1/6m9T+Fdshe1opAtZTy8= 2015-01-01                                          NaN
# /OrkK+agRQCMhB2GK3KctomRLGCQuWxUqw9ml1eQNog= 2015-01-01                                          NaN
#
#                                                          CUM_SUM(STD(logs.CUM_SUM(num_unq)))_6mos  \
# msno                                         time
# +6KodETinDioAsOrJjj1UH425xG3uM6N/bd49J15How= 2015-01-01                                       NaN
# +WiZkfIp5sDsf0xZvBnR2j6Kxi1u2k0t0mJBJqhQIJo= 2015-01-01                                       NaN
# +eELJ1gSSkwJItUOLgavd0hFy/TLj0RVrcaPgQunOPM= 2015-01-01                                       NaN
# +s3jJdEWKI0aVm/aTtJjbl1/6m9T+Fdshe1opAtZTy8= 2015-01-01                                       NaN
# /OrkK+agRQCMhB2GK3KctomRLGCQuWxUqw9ml1eQNog= 2015-01-01                                       NaN
#
#                                                          CUM_SUM(STD(transactions.CUM_SUM(actual_amount_paid)))_6mos  \
# msno                                         time
# +6KodETinDioAsOrJjj1UH425xG3uM6N/bd49J15How= 2015-01-01                                                NaN
# +WiZkfIp5sDsf0xZvBnR2j6Kxi1u2k0t0mJBJqhQIJo= 2015-01-01                                                NaN
# +eELJ1gSSkwJItUOLgavd0hFy/TLj0RVrcaPgQunOPM= 2015-01-01                                                NaN
# +s3jJdEWKI0aVm/aTtJjbl1/6m9T+Fdshe1opAtZTy8= 2015-01-01                                                NaN
# /OrkK+agRQCMhB2GK3KctomRLGCQuWxUqw9ml1eQNog= 2015-01-01                                                NaN
#
#                                                          CUM_SUM(SUM(logs.CUM_SUM(total_secs)))_6mos  \
# msno                                         time
# +6KodETinDioAsOrJjj1UH425xG3uM6N/bd49J15How= 2015-01-01                                          NaN
# +WiZkfIp5sDsf0xZvBnR2j6Kxi1u2k0t0mJBJqhQIJo= 2015-01-01                                          NaN
# +eELJ1gSSkwJItUOLgavd0hFy/TLj0RVrcaPgQunOPM= 2015-01-01                                   1204794.71
# +s3jJdEWKI0aVm/aTtJjbl1/6m9T+Fdshe1opAtZTy8= 2015-01-01                                          NaN
# /OrkK+agRQCMhB2GK3KctomRLGCQuWxUqw9ml1eQNog= 2015-01-01                                          NaN
#
#                                                          CUM_SUM(SUM(logs.CUM_SUM(num_985)))_6mos  \
# msno                                         time
# +6KodETinDioAsOrJjj1UH425xG3uM6N/bd49J15How= 2015-01-01                                       NaN
# +WiZkfIp5sDsf0xZvBnR2j6Kxi1u2k0t0mJBJqhQIJo= 2015-01-01                                       NaN
# +eELJ1gSSkwJItUOLgavd0hFy/TLj0RVrcaPgQunOPM= 2015-01-01                                     140.0
# +s3jJdEWKI0aVm/aTtJjbl1/6m9T+Fdshe1opAtZTy8= 2015-01-01                                       NaN
# /OrkK+agRQCMhB2GK3KctomRLGCQuWxUqw9ml1eQNog= 2015-01-01                                       NaN
#
#                                                          CUM_SUM(SUM(logs.CUM_SUM(num_50)))_6mos
# msno                                         time
# +6KodETinDioAsOrJjj1UH425xG3uM6N/bd49J15How= 2015-01-01                                      NaN
# +WiZkfIp5sDsf0xZvBnR2j6Kxi1u2k0t0mJBJqhQIJo= 2015-01-01                                      NaN
# +eELJ1gSSkwJItUOLgavd0hFy/TLj0RVrcaPgQunOPM= 2015-01-01                                    262.0
# +s3jJdEWKI0aVm/aTtJjbl1/6m9T+Fdshe1opAtZTy8= 2015-01-01                                      NaN
# /OrkK+agRQCMhB2GK3KctomRLGCQuWxUqw9ml1eQNog= 2015-01-01                                      NaN
#
# [5 rows x 834 columns]

# %%
kkbox_mo.df.shape
# Out:
# (18651, 834)

# %% [markdown]
# ## Prepping the Data
#
# Before running the kkbox_mo dataset through the automated modelling pipeline, human intervention will still be required to make sure the data is valid. We will drop rows with missing values in the `label` column, drop duplicates, keep our data to members whose birthdays are between 6 and 120, and fill in missing values with the mean.

# %%
fm = kkbox_mo.df.copy()
fm = fm.reset_index()
fm.drop(columns=["days_to_churn", "churn_date"], inplace=True)
fm = fm.dropna(subset=["label"])
fm = fm.drop_duplicates(subset = ['msno', 'time'])
fm = pd.get_dummies(fm.drop(columns=['time', 'msno']))
fm = fm[(fm.bd<120) & (fm.bd>6)]
fm = fm.fillna(fm.mean())

# %%
fm.shape
# Out:
# (7497, 838)

# %% [markdown]
# ## Feature Selection with the Automated Modeling Pipeline
#
# Now we will run the feature matrix through the pipeline. The pipeline applies functions in the order of its position in the pipeline. In this case, the order is:
#
# 1. DropMissing - columns with more than 70% missing values are dropped
# 2. DropDuplicate - duplicate columns are dropped
# 3. DropZeroCov - columns with zero variance are dropped (ie only have one value)
# 4. DropHighCorr - columns that have a correlation coefficient of 0.9 or more are dropped
# 5. RFSelector - features are ranked by importance using Random Forest and features that comprise 80% of total feature importance are kept

# %%
from sklearn.pipeline import Pipeline
from FeatureSelection import DropMissing, DropDuplicate, DropZeroCov, DropHighCorr, RFSelector

#Pipeline inputs can be repositioned depending on the user
RFPipeline = Pipeline([
    ('drop_missing', DropMissing(threshold=0.7)),
    ('drop_duplicate', DropDuplicate()),
    ('drop_zerocov', DropZeroCov()),
    ('drop_correlated', DropHighCorr(threshold=0.9)),
    ('RF_selector', RFSelector(num_feat=0.8))
])

#The same pipeline above is also callable through
from FeatureSelection import RFPipeline

# %%
X = fm.drop(columns=['label'])
y = fm['label']
kkbox_reduced = RFPipeline.fit_transform(X, y)
# Out:
# ---> 0 columns dropped due to missing values: []
# ---> 2 columns dropped due to duplicate values:
#
# ---> 1 columns dropped due to zero variance:
#  ['LAST(transactions.is_cancel)_3mos']
# ---> 561 columns dropped due to collinearity:
#  ['LAST(transactions.plan_list_price)', 'MIN(transactions.plan_list_price)', 'MEAN(logs.num_25)', 'MAX(logs.total_secs)', 'SUM(transactions.actual_amount_paid)', 'COUNT(transactions)', 'LAST(transactions.actual_amount_paid)', 'MODE(transactions.payment_method_id)', 'MAX(transactions.plan_list_price)', 'STD(logs.num_100)', 'SUM(logs.num_75)', 'MIN(transactions.payment_plan_days)', 'STD(transactions.payment_plan_days)', 'MAX(transactions.payment_plan_days)', 'SUM(transactions.payment_plan_days)', 'MEAN(transactions.payment_plan_days)', 'MIN(transactions.actual_amount_paid)', 'MEAN(transactions.plan_list_price)', 'STD(transactions.actual_amount_paid)', 'LAST(transactions.payment_plan_days)', 'CUM_SUM(MEAN(logs.num_unq))', 'CUM_SUM(NUM_UNIQUE(transactions.payment_method_id))', 'CUM_SUM(MEAN(logs.num_985))', 'CUM_SUM(MAX(logs.num_25))', 'CUM_SUM(STD(logs.num_985))', 'CUM_SUM(MAX(transactions.actual_amount_paid))', 'SUM(logs.CUM_SUM(num_50))', 'MAX(transactions.CUM_SUM(payment_plan_days))', 'CUM_SUM(MIN(transactions.plan_list_price))', 'CUM_SUM(MAX(logs.num_75))', 'LAST(logs.CUM_SUM(num_100))', 'LAST(logs.CUM_SUM(num_unq))', 'CUM_SUM(STD(transactions.payment_plan_days))', 'CUM_SUM(SUM(transactions.plan_list_price))', 'CUM_SUM(SUM(logs.num_50))', 'MIN(logs.CUM_SUM(num_unq))', 'CUM_SUM(MIN(logs.num_50))', 'CUM_SUM(MEAN(logs.num_50))', 'NUM_UNIQUE(transactions.MONTH(membership_expire_date))', 'CUM_SUM(MAX(logs.num_100))', 'SUM(logs.CUM_SUM(total_secs))', 'MIN(transactions.CUM_SUM(actual_amount_paid))', 'CUM_SUM(MIN(logs.num_unq))', 'MEAN(logs.CUM_SUM(num_unq))', 'MEAN(transactions.CUM_SUM(plan_list_price))', 'CUM_SUM(STD(transactions.actual_amount_paid))', 'CUM_SUM(LAST(logs.num_unq))', 'CUM_SUM(LAST(transactions.plan_list_price))', 'CUM_SUM(STD(logs.num_100))', 'LAST(logs.CUM_SUM(num_50))', 'CUM_SUM(LAST(logs.num_25))', 'CUM_SUM(MAX(logs.total_secs))', 'CUM_SUM(MEAN(transactions.actual_amount_paid))', 'CUM_SUM(MEAN(logs.num_100))', 'CUM_SUM(SUM(transactions.payment_plan_days))', 'CUM_SUM(STD(logs.num_75))', 'CUM_SUM(SUM(logs.num_985))', 'MAX(logs.CUM_SUM(num_985))', 'MIN(logs.CUM_SUM(num_985))', 'CUM_SUM(LAST(transactions.actual_amount_paid))', 'CUM_SUM(MAX(transactions.plan_list_price))', 'MIN(transactions.CUM_SUM(plan_list_price))', 'SUM(transactions.CUM_SUM(payment_plan_days))', 'SUM(logs.CUM_SUM(num_985))', 'STD(logs.CUM_SUM(num_985))', 'MIN(transactions.CUM_SUM(payment_plan_days))', 'LAST(logs.CUM_SUM(num_75))', 'MEAN(transactions.CUM_SUM(actual_amount_paid))', 'MAX(transactions.CUM_SUM(actual_amount_paid))', 'CUM_SUM(TIME_SINCE_LAST(transactions.transaction_date))', 'CUM_SUM(STD(transactions.plan_list_price))', 'SUM(logs.CUM_SUM(num_100))', 'CUM_SUM(MAX(logs.num_985))', 'CUM_SUM(SUM(logs.num_unq))', 'CUM_SUM(MEAN(transactions.payment_plan_days))', 'MEAN(logs.CUM_SUM(num_25))', 'CUM_SUM(STD(logs.num_50))', 'MEAN(logs.CUM_SUM(num_50))', 'CUM_SUM(TIME_SINCE_LAST(logs.date))', 'CUM_SUM(LAST(logs.num_75))', 'LAST(logs.CUM_SUM(total_secs))', 'CUM_SUM(STD(logs.num_25))', 'CUM_SUM(SUM(logs.num_100))', 'STD(logs.CUM_SUM(num_25))', 'CUM_SUM(MEAN(logs.num_75))', 'CUM_SUM(MAX(logs.num_unq))', 'CUM_SUM(MAX(logs.num_50))', 'CUM_SUM(SUM(logs.num_25))', 'CUM_SUM(STD(logs.total_secs))', 'CUM_SUM(STD(logs.num_unq))', 'MIN(logs.CUM_SUM(num_50))', 'CUM_SUM(MIN(logs.num_100))', 'CUM_SUM(AVG_TIME_BETWEEN(transactions.transaction_date))', 'SUM(logs.CUM_SUM(num_unq))', 'CUM_SUM(SUM(logs.num_75))', 'CUM_SUM(PERCENT_TRUE(transactions.is_auto_renew))', 'CUM_SUM(COUNT(logs))', 'CUM_SUM(MIN(logs.num_75))', 'CUM_SUM(MIN(logs.total_secs))', 'MIN(logs.CUM_SUM(num_75))', 'CUM_SUM(MEAN(transactions.plan_list_price))', 'STD(transactions.CUM_SUM(plan_list_price))', 'CUM_SUM(MEAN(logs.num_25))', 'STD(logs.CUM_SUM(num_75))', 'STD(logs.CUM_SUM(num_unq))', 'SUM(transactions.CUM_SUM(plan_list_price))', 'STD(logs.CUM_SUM(num_100))', 'MEAN(logs.CUM_SUM(num_100))', 'CUM_SUM(MIN(logs.num_25))', 'MAX(logs.CUM_SUM(total_secs))', 'CUM_SUM(COUNT(transactions))', 'SUM(logs.CUM_ ...
# /home/sahil94/.local/lib/python3.5/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
RFPipeline.named_steps["RF_selector"].plot_importance()

# %%
print("Shape of KKBOX dataset after feature extraction: ", kkbox_mo.df.shape)
print("Shape of KKBOX dataset after feature selection: ", kkbox_reduced.shape)
print("Number of features dropped: ", kkbox_mo.df.shape[1]-kkbox_reduced.shape[1])
# Out:
# Shape of KKBOX dataset after feature extraction:  (18651, 834)
# Shape of KKBOX dataset after feature selection:  (7497, 57)
# Number of features dropped:  777

# %% [markdown]
# ## Modelling the Data with Light GBM
#
# Now we will run the reduced KKBOX dataset through Light GBM

# %%
import lightgbm as lgb

RSEED = 40

def cross_validate(X, y):
    """Compute cross validation ROC AUC of a gradient boosting model for a given training dataset"""
    
    # Extract the labels
    train_labels = y
    train = X

    # Create a  lgb training set
    train_set = lgb.Dataset(train, label = train_labels)

    # Find default hyperparameters
    model = lgb.LGBMClassifier()
    params = model.get_params()

    # Number of estimators will be selected through early stopping
    del params['n_estimators'], params['silent']

    # Early stoppping with 5 fold cross validation
    cv_results = lgb.cv(params, train_set, num_boost_round = 10000, metrics = 'auc', 
                        early_stopping_rounds = 100, seed = RSEED, nfold = 5)

    print('Cross Validation ROC AUC: {:.5f} with std: {:.5f}.'.format(cv_results['auc-mean'][-1],
                                                                               cv_results['auc-stdv'][-1]))

    print('Number of estimators trained: {}'.format(len(cv_results['auc-mean'])))
    
    return cv_results

# %%
cv_results_baseline = cross_validate(kkbox_reduced, y)
# Out:
# Cross Validation ROC AUC: 0.89829 with std: 0.02676.
# Number of estimators trained: 49

# %%
## Feature Importance
X = kkbox_reduced

# New model fit on the training data
model = lgb.LGBMClassifier(n_estimators = len(cv_results_baseline['auc-mean']), random_state = RSEED)
model.fit(X, y)

# Put feature importances into a dataframe
feature_importances = pd.DataFrame({'feature': list(X.columns), 
                                    'importance': model.feature_importances_})

import matplotlib.pyplot as plt

def plot_feature_importances(df):
    
    plt.rcParams['font.size'] = 18
    
    # Sort features according to importance
    df = df.sort_values('importance', ascending = False).reset_index()
    
    # Normalize the feature importances to add up to one
    df['importance_normalized'] = df['importance'] / df['importance'].sum()
    df['cumulative_importance'] = np.cumsum(df['importance_normalized'])

    # Make a horizontal bar chart of feature importances
    plt.figure(figsize = (10, 6))
    ax = plt.subplot()
    
    # Need to reverse the index to plot most important on top
    ax.barh(list(reversed(list(df.index[:15]))), 
            df['importance_normalized'].head(15), 
            align = 'center', edgecolor = 'k')
    
    # Set the yticks and labels
    ax.set_yticks(list(reversed(list(df.index[:15]))))
    ax.set_yticklabels(df['feature'].head(15))
    
    # Plot labeling
    plt.xlabel('Normalized Importance'); plt.title('Feature Importances')
    plt.show()

    
    return df
norm_fi = plot_feature_importances(feature_importances)
norm_fi.head(20)
# Out:
#     index                                          feature  importance  \
# 0       1   TIME_SINCE_LAST(transactions.transaction_date)         162
# 1      53  AVG_TIME_BETWEEN(transactions.transaction_date)          63
# 2      40   LAST(transactions.DAY(membership_expire_date))          55
# 3      11      LAST(transactions.CUM_SUM(plan_list_price))          51
# 4      27                      AVG_TIME_BETWEEN(logs.date)          43
# 5      23                               LAST(logs.num_unq)          40
# 6      44                            LAST(logs.total_secs)          39
# 7      19                                 STD(logs.num_25)          37
# 8      47    SUM(transactions.CUM_SUM(actual_amount_paid))          37
# 9       8                STD(transactions.plan_list_price)          35
# 10      5         DAY(LAST(transactions.transaction_date))          33
# 11      9                    CUM_SUM(SUM(logs.total_secs))          31
# 12     46                                MAX(logs.num_100)          31
# 13     16                                 STD(logs.num_50)          30
# 14     31                                MEAN(logs.num_50)          28
# 15      3                    STD(logs.CUM_SUM(total_secs))          28
# 16     21   MODE(transactions.DAY(membership_expire_date))          27
# 17     18    MEAN(transactions.CUM_SUM(payment_plan_days))          27
# 18     36                                               bd          26
# 19     51                      DAY(registration_init_time)          26
#
#     importance_normalized  cumulative_importance
# 0                0.110204               0.110204
# 1                0.042857               0.153061
# 2                0.037415               0.190476
# 3                0.034694               0.225170
# 4                0.029252               0.254422
# 5                0.027211               0.281633
# 6                0.026531               0.308163
# 7                0.025170               0.333333
# 8                0.025170               0.358503
# 9                0.023810               0.382313
# 10               0.022449               0.404762
# 11               0.021088               0.425850
# 12               0.021088               0.446939
# 13               0.020408               0.467347
# 14               0.019048               0.486395
# 15               0.019048               0.505442
# 16               0.018367               0.523810
# 17               0.018367               0.542177
# 18               0.017687               0.559864
# 19               0.017687               0.577551
